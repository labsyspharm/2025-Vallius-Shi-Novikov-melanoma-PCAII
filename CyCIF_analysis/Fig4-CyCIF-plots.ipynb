# %% [markdown]
# ## Vallius, Shi, Novikov et al. 2026

# %% [markdown]
# ### Fig 4 CyCIF proportion plots

# %%
import sys
import os
import anndata as ad
import pandas as pd
import scanpy as sc
import re
import numpy as np
import seaborn as sns; sns.set(color_codes=True)
import scimap as sm  
from matplotlib import pyplot as plt
from matplotlib.patches import Patch
from scipy.stats import pearsonr
import napari
# Out:
# Running SCIMAP  2.1.0

# %% [markdown]
# #### Panel 2 (e41) MEL18 plots

# %%
#input data "Fig4-MEL18-data-for-plotting.h5ad"
adata_MEL18=ad.read(r".\Fig4-MEL18-data-for-plotting.h5ad")
# Out:
# C:\Users\tav9\AppData\Local\anaconda3\envs\scimap_new\lib\site-packages\anndata\__init__.py:55: FutureWarning:
#
# `anndata.read` is deprecated, use `anndata.read_h5ad` instead. `ad.read` will be removed in mid 2024.

# %%
adata_MEL18
# Out:
# AnnData object with n_obs × n_vars = 72425 × 42
#     obs: 'X_centroid', 'Y_centroid', 'Area', 'MajorAxisLength', 'MinorAxisLength', 'Eccentricity', 'Solidity', 'Extent', 'Orientation', 'CellID', 'imageid', 'ROI', 'ROI_major_category', 'phenotype', 'MEL_id', 'B2Mpos', 'ROI_rename', 'MART1pos', 'PMELpos', 'ECADpos', 'SOX9pos', 'S100Apos', 'SOX10pos', 'ROI_MEL18'
#     uns: 'all_markers', 'gates', 'spatial_distance'

# %%
y=['SOX10-','SOX10+']
x=['MEL18_015','MEL18_016','MEL18_027','MEL18_026']
b=sm.pl.stacked_barplot(adata_MEL18, y_axis='SOX10pos', x_axis='ROI_MEL18', 
                      subset_xaxis=x, subset_yaxis=y, order_xaxis=None, order_yaxis=None, 
                      method='percent', figsize=(2,3), return_data=True, fileName='MEL18_geoMX_SOX10-e41.pdf', saveDir='C:/Users/tav9/HMS Dropbox/Tuulia Vallius/test/test/')
# Out:
# Saved plot to C:/Users/tav9/HMS Dropbox/Tuulia Vallius/test/test/MEL18_geoMX_SOX10-e41.pdf

# %%
y=['MART1-','MART1+']
x=['MEL18_015','MEL18_016','MEL18_027','MEL18_026']
b=sm.pl.stacked_barplot(adata_MEL18, y_axis='MART1pos', x_axis='ROI_MEL18', 
                      subset_xaxis=x, subset_yaxis=y, order_xaxis=None, order_yaxis=None, 
                      method='percent', figsize=(2,3), return_data=True, fileName='MEL18_geoMX_MART1.pdf', saveDir='C:/Users/tav9/HMS Dropbox/Tuulia Vallius/test/test/')
# Out:
# Saved plot to C:/Users/tav9/HMS Dropbox/Tuulia Vallius/test/test/MEL18_geoMX_MART1.pdf

# %%
y=['SOX9-','SOX9+']
x=['MEL18_015','MEL18_016','MEL18_027','MEL18_026']
b=sm.pl.stacked_barplot(adata_MEL18, y_axis='SOX9pos', x_axis='ROI_MEL18', 
                      subset_xaxis=x, subset_yaxis=y, order_xaxis=None, order_yaxis=None, 
                      method='percent', figsize=(2,3), return_data=True, fileName='MEL18_geoMX_SOX9.pdf', saveDir='C:/Users/tav9/HMS Dropbox/Tuulia Vallius/test/test/')
# Out:
# Saved plot to C:/Users/tav9/HMS Dropbox/Tuulia Vallius/test/test/MEL18_geoMX_SOX9.pdf

# %%
y=['S100A-','S100A+']
x=['MEL18_015','MEL18_016','MEL18_027','MEL18_026']
b=sm.pl.stacked_barplot(adata_MEL18, y_axis='S100Apos', x_axis='ROI_MEL18', 
                      subset_xaxis=x, subset_yaxis=y, order_xaxis=None, order_yaxis=None, 
                      method='percent', figsize=(2,3), return_data=True, fileName='MEL18_geoMX_S100A.pdf', saveDir='C:/Users/tav9/HMS Dropbox/Tuulia Vallius/test/test/')
# Out:
# Saved plot to C:/Users/tav9/HMS Dropbox/Tuulia Vallius/test/test/MEL18_geoMX_S100A.pdf

# %%
y=['PMEL-','PMEL+']
x=['MEL18_015','MEL18_016','MEL18_027','MEL18_026']
b=sm.pl.stacked_barplot(adata_MEL18, y_axis='PMELpos', x_axis='ROI_MEL18', 
                      subset_xaxis=x, subset_yaxis=y, order_xaxis=None, order_yaxis=None, 
                      method='percent', figsize=(2,3), return_data=True, fileName='MEL18_geoMX_PMEL.pdf', saveDir='C:/Users/tav9/HMS Dropbox/Tuulia Vallius/test/test/')
# Out:
# Saved plot to C:/Users/tav9/HMS Dropbox/Tuulia Vallius/test/test/MEL18_geoMX_PMEL.pdf

# %% [markdown]
# #### Panel 1 (e24) MEL18 plots

# %%
adata_MEL18=ad.read(r"C:\Users\tav9\HMS Dropbox\Tuulia Vallius\2024-Vallius-Novikov-Shi-Melanoma_PCA\supplementary materials\CyCIF_data_for_plotting\Fig4-MEL18-MITF-data.h5ad")
# Out:
# C:\Users\tav9\AppData\Local\anaconda3\envs\scimap_new\lib\site-packages\anndata\__init__.py:55: FutureWarning:
#
# `anndata.read` is deprecated, use `anndata.read_h5ad` instead. `ad.read` will be removed in mid 2024.

# %%
sm.hl.classify(adata_MEL18, pos=['MITF'], neg=None, classify_label='MITF+', phenotype='phenotype_v2', 
               subclassify_phenotype='Melanocyte', threshold=0.5, collapse_failed=False, label='MITFpos')
rename= {'MITF+': ['MITF+'],
        'MITF-':['Melanocyte']}
adata_MEL18 = sm.hl.rename(adata_MEL18, rename, from_column='MITFpos', to_column='MITFpos')
# Out:
# Renaming MITF+ to MITF+
# Renaming Melanocyte to MITF-

# %%
y=['MITF-','MITF+']
x=['LSP13135_015','LSP13135_016','LSP13135_027','LSP13135_026']
b=sm.pl.stacked_barplot(adata_MEL18, y_axis='MITFpos', x_axis='ROI_GeoMX', 
                      subset_xaxis=x, subset_yaxis=y, order_xaxis=None, order_yaxis=None, 
                      method='percent', figsize=(2,3), return_data=True, fileName='MEL18_geoMX_MITF.pdf', saveDir='C:/Users/tav9/HMS Dropbox/Tuulia Vallius/test/test/')

b.to_csv(r"C:\Users\tav9\HMS Dropbox\Tuulia Vallius\2024-Vallius-Novikov-Shi-Melanoma_PCA\supplementary materials\CyCIF_data_for_plotting\Fig4-MEL18-MITF-data.csv")
# Out:
# Saved plot to C:/Users/tav9/HMS Dropbox/Tuulia Vallius/test/test/MEL18_geoMX_MITF.pdf

# %% [markdown]
# #### Panel 2 (e41) MEL25 plots

# %%
adata_MEL25=ad.read(r".\Fig4-MEL25-data-e41.h5ad")
# Out:
# C:\Users\tav9\AppData\Local\anaconda3\envs\scimap_new\lib\site-packages\anndata\__init__.py:55: FutureWarning:
#
# `anndata.read` is deprecated, use `anndata.read_h5ad` instead. `ad.read` will be removed in mid 2024.

# %%
y=['S100A-','S100A+']
x=['MEL25_061','MEL25_062','MEL25_065','MEL25_059']
b=sm.pl.stacked_barplot(adata_MEL25, y_axis='S100Apos', x_axis='MEL25_ROI_geoMX', 
                      subset_xaxis=x, subset_yaxis=y, order_xaxis=x, order_yaxis=None, 
                      method='percent', figsize=(2,3), return_data=True, fileName='MEL25_geoMX_S100A.pdf', saveDir='C:/Users/tav9/HMS Dropbox/Tuulia Vallius/test/test/')

# %%
y=['SOX9-','SOX9+']
x=['MEL25_061','MEL25_062','MEL25_065','MEL25_059']
b=sm.pl.stacked_barplot(adata_MEL25, y_axis='SOX9pos', x_axis='MEL25_ROI_geoMX', 
                      subset_xaxis=x, subset_yaxis=y, order_xaxis=x, order_yaxis=None, 
                      method='percent', figsize=(2,3), return_data=True, fileName='MEL25_geoMX_SOX9.pdf', saveDir='C:/Users/tav9/HMS Dropbox/Tuulia Vallius/test/test/')

# %%
y=['SOX10-','SOX10+']
x=['MEL25_061','MEL25_062','MEL25_065','MEL25_059']
b=sm.pl.stacked_barplot(adata_MEL25, y_axis='SOX10pos', x_axis='MEL25_ROI_geoMX', 
                      subset_xaxis=x, subset_yaxis=y, order_xaxis=x, order_yaxis=None, 
                      method='percent', figsize=(2,3), return_data=True, fileName='MEL25_geoMX_SOX10.pdf', saveDir='C:/Users/tav9/HMS Dropbox/Tuulia Vallius/test/test/')

# %%
y=['PMEL-','PMEL+']
x=['MEL25_061','MEL25_062','MEL25_065','MEL25_059']
b=sm.pl.stacked_barplot(adata_MEL25, y_axis='PMELpos', x_axis='MEL25_ROI_geoMX', 
                      subset_xaxis=x, subset_yaxis=y, order_xaxis=x, order_yaxis=None, 
                      method='percent', figsize=(2,3), return_data=True, fileName='MEL25_geoMX_PMEL.pdf', saveDir='C:/Users/tav9/HMS Dropbox/Tuulia Vallius/test/test/')

# %%
y=['MART1-','MART1+']
x=['MEL25_061','MEL25_062','MEL25_065','MEL25_059']
b=sm.pl.stacked_barplot(adata_MEL25, y_axis='MART1pos', x_axis='MEL25_ROI_geoMX', 
                      subset_xaxis=x, subset_yaxis=y, order_xaxis=x, order_yaxis=None, 
                      method='percent', figsize=(2,3), return_data=True, fileName='MEL25_geoMX_MART1.pdf', saveDir='C:/Users/tav9/HMS Dropbox/Tuulia Vallius/test/test/')

# %% [markdown]
# #### Panel 1 (e24) MEL25 data

# %%
adata_MEL25=ad_read(r"C:\Users\tav9\HMS Dropbox\Tuulia Vallius\2024-Vallius-Novikov-Shi-Melanoma_PCA\supplementary materials\CyCIF_data_for_plotting\Fig4-MEL25-MITF-data-for-plotting.h5ad")

# %%
sm.hl.classify(adata_MEL25, pos=['MITF'], neg=None, classify_label='MITF+', phenotype='phenotype_v2', 
               subclassify_phenotype='Melanocyte', threshold=0.5, collapse_failed=False, label='MITFpos')
rename= {'MITF+': ['MITF+'],
        'MITF-':['Melanocyte']}
adata_MEL25 = sm.hl.rename(adata_MEL25, rename, from_column='MITFpos', to_column='MITFpos')

# %%
y=['MITF-','MITF+']
x=['LSP13145_061','LSP13145_062','LSP13145_065','LSP13145_059']
b=sm.pl.stacked_barplot(adata_MEL25, y_axis='MITFpos', x_axis='ROI_GeoMX', 
                      subset_xaxis=x, subset_yaxis=y, order_xaxis=None, order_yaxis=None, 
                      method='percent', figsize=(2,3), return_data=True, fileName='MEL25_geoMX_MITF.pdf', saveDir='C:/Users/tav9/HMS Dropbox/Tuulia Vallius/test/test/')
