# %% [markdown]
# ## Vallius, Shi, Novikov et al. 2026

# %% [markdown]
# ### Fig 6B CyCIF RCN

# %%
import sys
import os
import anndata as ad
import pandas as pd
import scanpy as sc
import re
import numpy as np
import seaborn as sns; sns.set(color_codes=True)
import scimap as sm  
from matplotlib import pyplot as plt
from matplotlib.patches import Patch
from scipy.stats import pearsonr
import napari
# Out:
# Running SCIMAP  2.1.0

# %%
data=pd.read_csv(r"C:\Users\tav9\HMS Dropbox\Tuulia Vallius\2024-Vallius-Novikov-Shi-Melanoma_PCA\supplementary materials\CyCIF_data_for_plotting\Fig6B.csv")

# %%
sns.clustermap(data, cmap="viridis", vmin=0, vmax=0.5, col_cluster=False, figsize=(5,9))

# %% [markdown]
# ### Fig 6E

# %%
a=pd.read_csv(r"C:\Users\tav9\HMS Dropbox\Tuulia Vallius\2024-Vallius-Novikov-Shi-Melanoma_PCA\supplementary materials\CyCIF_data_for_plotting\Fig6E.csv")

# %%
sns.lineplot(data=a, dashes=False)

# %% [markdown]
# ### Fig 6F

# %%
group_df=pd.read_csv(r"C:\Users\tav9\HMS Dropbox\Tuulia Vallius\2024-Vallius-Novikov-Shi-Melanoma_PCA\supplementary materials\CyCIF_data_for_plotting\Fig6F.csv")

# %%
plt.rcParams["figure.figsize"] = (4,3)

sns.stripplot(data=group_df, x="spatial_cluster_RCNG", y="spatial_cluster_RCNG.1", hue="Branch_ID", hue_order=['branch1','branch3'], 
              order=['RCNG11', 'RCNG7','RCNG10','RCNG8','RCNG3','RCNG4','RCNG1','RCNG2','RCNG5','RCNG6','RCNG9'], legend=False, dodge=True, color='black', s=1)
ax=sns.boxplot(data=group_df, x='spatial_cluster_RCNG', y='spatial_cluster_RCNG.1', hue='Branch_ID',hue_order=['branch1','branch3'], 
               order=['RCNG11', 'RCNG7','RCNG10','RCNG8','RCNG3','RCNG4','RCNG1','RCNG2','RCNG5','RCNG6','RCNG9'], palette=['red','dodgerblue'],fill=True, gap=.1,fliersize=1)
ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
