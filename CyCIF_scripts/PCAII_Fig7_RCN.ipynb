# %%
# Vallius & Shi et al 2025
# Fig 6 & Suppl Fig 6

# %%
# This notebook was generated on 5/28/2025 to create the plots in Fig 6

# %%
import sys
import os
import anndata as ad
import pandas as pd
import scanpy as sc
import re
import numpy as np
import seaborn as sns; sns.set(color_codes=True)
import scimap as sm  
from matplotlib import pyplot as plt
from matplotlib.patches import Patch
from scipy.stats import pearsonr
import scipy.stats as stats

os.chdir("C:/Users/tav9/Dropbox (HMS)/PCA_phaseII/cycif_analysis_materials/data/TV")
import napari
# Out:
# Running SCIMAP  2.1.0

# %%
adata=ad.read("./e24_entropy_cycif_mapping_09122024.h5ad")
# Out:
# C:\Users\tav9\AppData\Local\anaconda3\envs\scimap_new\lib\site-packages\anndata\__init__.py:55: FutureWarning:
#
# `anndata.read` is deprecated, use `anndata.read_h5ad` instead. `ad.read` will be removed in mid 2024.

# %%
rename={'branch1':['LSP13987_011','LSP13987_012','LSP13987_013','LSP13987_014','LSP13987_016','LSP13987_017','LSP13968_003','LSP13968_004','LSP13968_005','LSP13968_007','LSP13968_009','LSP13968_010','LSP13968_012','LSP13968_019','LSP13968_030','LSP13968_036','LSP13968_037','LSP13975_015','LSP13975_023','LSP13975_024','LSP13975_028','LSP13975_029','LSP13975_030','LSP13975_031','LSP13987_001','LSP13987_002','LSP13987_003','LSP13987_004','LSP13987_005','LSP13987_006','LSP13987_007','LSP13987_008','LSP13987_009','LSP13987_010','LSP13939_023','LSP13939_024','LSP13939_025','LSP13939_026','LSP13939_027','LSP13939_028','LSP13939_029','LSP13943_004','LSP13932_020','LSP13932_023','LSP13947_001','LSP13947_004','LSP13947_005','LSP13947_006','LSP13947_007','LSP13947_008','LSP13947_009','LSP13947_010','LSP13947_014','LSP13947_015','LSP13947_017','LSP13947_018','LSP13996_001','LSP13996_002','LSP13996_003','LSP13996_005','LSP13985_001','LSP13985_002','LSP13985_003','LSP13985_004','LSP13961_023','LSP13961_024','LSP13961_025','LSP13961_028','LSP13961_030','LSP13961_031','LSP13961_032','LSP13961_034','LSP13914_005','LSP13914_006','LSP13914_007','LSP13914_008','LSP13914_009','LSP13914_011','LSP13914_012','LSP13914_014','LSP13914_015','LSP13914_017','LSP13918_006','LSP13918_007','LSP13918_029','LSP13918_041','LSP13918_043','LSP13918_045'],
'branch2':['LSP13987_015','LSP13968_014','LSP13968_016','LSP13968_020','LSP13968_025','LSP13968_028','LSP13968_039','LSP13975_025','LSP13975_032','LSP13939_020','LSP13939_021','LSP13939_022','LSP13939_031','LSP13932_008','LSP13932_009','LSP13932_017','LSP13932_018','LSP13932_019','LSP13932_022','LSP13932_026','LSP13932_027','LSP13932_028','LSP13961_014','LSP13961_016','LSP13961_017','LSP13918_005','LSP13918_039','LSP13918_040','LSP13918_044'],
'branch3':['LSP13968_001','LSP13968_002','LSP13968_015','LSP13968_017','LSP13968_027','LSP13968_031','LSP13968_033','LSP13968_034','LSP13968_038','LSP13975_003','LSP13975_008','LSP13975_009','LSP13975_018','LSP13975_020','LSP13975_021','LSP13975_022','LSP13925_005','LSP13925_006','LSP13925_007','LSP13925_008','LSP13925_013','LSP13925_020','LSP13925_021','LSP13925_023','LSP13925_024','LSP13925_025','LSP13925_027','LSP13925_029','LSP13925_030','LSP13939_003','LSP13939_004','LSP13939_005','LSP13939_006','LSP13939_007','LSP13939_008','LSP13939_011','LSP13939_012','LSP13939_014','LSP13939_015','LSP13939_016','LSP13939_018','LSP13943_002','LSP13943_003','LSP13943_005','LSP13943_006','LSP13943_007','LSP13943_008','LSP13943_009','LSP13943_011','LSP13943_012','LSP13943_013','LSP13943_014','LSP13943_015','LSP13943_016','LSP13932_003','LSP13932_004','LSP13932_006','LSP13996_012','LSP13996_013','LSP13996_014','LSP13996_016','LSP13996_017','LSP13996_019','LSP13996_021','LSP13985_008','LSP13985_009','LSP13985_010','LSP13985_012','LSP13985_013','LSP13985_014','LSP13961_004','LSP13961_005','LSP13961_006','LSP13961_007','LSP13961_008','LSP13961_009','LSP13961_010','LSP13961_011','LSP13961_035','LSP13918_028','LSP13918_030','LSP13918_031','LSP13918_035','LSP13918_042','LSP13954_001','LSP13954_002','LSP13954_003','LSP13954_004','LSP13954_005','LSP13954_006','LSP13954_007','LSP13954_008','LSP13954_010','LSP13954_011','LSP13954_012','LSP13954_013','LSP13954_014']}

adata = sm.hl.rename(adata, rename, from_column='ROI_GeoMX', to_column='SOM_branch_ID')
# Out:
# Renaming LSP13987_011 to branch1
# Renaming LSP13987_012 to branch1
# Renaming LSP13987_013 to branch1
# Renaming LSP13987_014 to branch1
# Renaming LSP13987_016 to branch1
# Renaming LSP13987_017 to branch1
# Renaming LSP13968_003 to branch1
# Renaming LSP13968_004 to branch1
# Renaming LSP13968_005 to branch1
# Renaming LSP13968_007 to branch1
# Renaming LSP13968_009 to branch1
# Renaming LSP13968_010 to branch1
# Renaming LSP13968_012 to branch1
# Renaming LSP13968_019 to branch1
# Renaming LSP13968_030 to branch1
# Renaming LSP13968_036 to branch1
# Renaming LSP13968_037 to branch1
# Renaming LSP13975_015 to branch1
# Renaming LSP13975_023 to branch1
# Renaming LSP13975_024 to branch1
# Renaming LSP13975_028 to branch1
# Renaming LSP13975_029 to branch1
# Renaming LSP13975_030 to branch1
# Renaming LSP13975_031 to branch1
# Renaming LSP13987_001 to branch1
# Renaming LSP13987_002 to branch1
# Renaming LSP13987_003 to branch1
# Renaming LSP13987_004 to branch1
# ...

# %%
adata2=ad.read(r'C:\Users\tav9\HMS Dropbox\Tuulia Vallius\2024-Vallius-Novikov-Shi-Melanoma_PCA\data\e24\RCN\e24_RCN_data.h5ad')
# Out:
# C:\Users\tav9\AppData\Local\anaconda3\envs\scimap_new\lib\site-packages\anndata\__init__.py:55: FutureWarning:
#
# `anndata.read` is deprecated, use `anndata.read_h5ad` instead. `ad.read` will be removed in mid 2024.

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 1421335 × 46
#     obs: 'X_centroid', 'Y_centroid', 'Area', 'MajorAxisLength', 'MinorAxisLength', 'Eccentricity', 'Solidity', 'Extent', 'Orientation', 'CellID', 'imageid', 'ROI', 'ROI_major_category', 'ROI_minor_category', 'phenotype', 'phenotype_v2', 'MELid', 'ROI_LSP11347', 'IRF1pos', 'ROI_GeoMX', 'ROI_GeoMX_expanded', 'MART1pos', 'entropy_status', 'SOM_branch_ID'
#     uns: 'all_markers', 'gates'

# %%
adata2.obs['index_col']=adata2.obs.index
adata.obs['index_col']=adata.obs.index

common_column = 'index_col'
adata2.obs = adata2.obs.join(adata.obs[['SOM_branch_ID']], on=common_column, how='left')

# %%
adata2
# Out:
# AnnData object with n_obs × n_vars = 1208962 × 46
#     obs: 'X_centroid', 'Y_centroid', 'Area', 'MajorAxisLength', 'MinorAxisLength', 'Eccentricity', 'Solidity', 'Extent', 'Orientation', 'CellID', 'imageid', 'ROI', 'ROI_major_category', 'ROI_minor_category', 'phenotype', 'phenotype_v2', 'MELid', 'PCNApos', 'KI67pos', 'MARTpos', 'lineage', 'lineage_grouped', 'lose_08032023', 'proliferation', 'proliferation2', 'prolif2_lineage', 'imageid_raw', 'MART1pos', 'spatial_cluster_kmeans_25', 'spatial_cluster_grouped', 'index_col', 'ROI_GeoMX', 'SOM_branch_ID'
#     uns: 'all_markers', 'gates', 'lineage_colors', 'spatial_count_MART', 'spatial_distance_MART'

# %%
#Image path

LSP11563 = "Y:/cycif-production/16-Pre-Cancer-Atlas-for-Melanoma/PCAII_p16_e24/mcmicro_done/13Cycles/LSP11563/registration/LSP11563.ome.tif"
LSP11523 = "Y:/cycif-production/16-Pre-Cancer-Atlas-for-Melanoma/PCAII_p16_e24/mcmicro_done/13Cycles/LSP11523/registration/LSP11523.ome.tif"
LSP11587 = "Y:/cycif-production/16-Pre-Cancer-Atlas-for-Melanoma/PCAII_p16_e24/mcmicro_done/13Cycles/LSP11587/registration/LSP11587.ome.tif"
LSP11747 = "Y:/cycif-production/16-Pre-Cancer-Atlas-for-Melanoma/PCAII_p16_e24/mcmicro_done/13Cycles/LSP11747/registration/LSP11747.ome.tif"
LSP11411 = "Y:/cycif-production/16-Pre-Cancer-Atlas-for-Melanoma/PCAII_p16_e24/mcmicro_done/re-processed/LSP11411/registration/LSP11411.ome.tif"
LSP11691 = "Y:/cycif-production/16-Pre-Cancer-Atlas-for-Melanoma/PCAII_p16_e24/mcmicro_done/13Cycles/LSP11691/registration/LSP11691.ome.tif"
LSP11483 = "Y:/cycif-production/16-Pre-Cancer-Atlas-for-Melanoma/PCAII_p16_e24/mcmicro_done/13Cycles/LSP11483/registration/LSP11483.ome.tif"
LSP11595 = "Y:/cycif-production/16-Pre-Cancer-Atlas-for-Melanoma/PCAII_p16_e24/mcmicro_done/13Cycles/LSP11595/registration/LSP11595.ome.tif"
LSP11627 = "Y:/cycif-production/16-Pre-Cancer-Atlas-for-Melanoma/PCAII_p16_e24/mcmicro_done/13Cycles/LSP11627/registration/LSP11627.ome.tif"
LSP11315 = "Y:/cycif-production/16-Pre-Cancer-Atlas-for-Melanoma/PCAII_p16_e24/mcmicro_done/13Cycles/LSP11315/registration/LSP11315.ome.tif"
LSP11419 = "Y:/cycif-production/16-Pre-Cancer-Atlas-for-Melanoma/PCAII_p16_e24/mcmicro_done/re-processed/LSP11419/registration/LSP11419.ome.tif"
LSP11355 = "Y:/cycif-production/16-Pre-Cancer-Atlas-for-Melanoma/PCAII_p16_e24/mcmicro_done/13Cycles/LSP11355/registration/LSP11355.ome.tif"
LSP11387 = "Y:/cycif-production/16-Pre-Cancer-Atlas-for-Melanoma/PCAII_p16_e24/mcmicro_done/13Cycles/LSP11387/registration/LSP11387.ome.tif"
LSP11403 = "Y:/cycif-production/16-Pre-Cancer-Atlas-for-Melanoma/PCAII_p16_e24/mcmicro_done/13Cycles/LSP11403/registration/LSP11403.ome.tif"
LSP11339 = "Y:/cycif-production/16-Pre-Cancer-Atlas-for-Melanoma/PCAII_p16_e24/mcmicro_done/13Cycles/LSP11339/registration/LSP11339.ome.tif"
LSP11667 = "Y:/cycif-production/16-Pre-Cancer-Atlas-for-Melanoma/PCAII_p16_e24/mcmicro_done/13Cycles/LSP11667/registration/LSP11667.ome.tif"
LSP11347 = "Y:/cycif-production/16-Pre-Cancer-Atlas-for-Melanoma/PCAII_p16_e24/mcmicro_done/13Cycles/LSP11347/registration/LSP11347.ome.tif"
LSP11395 = "Y:/cycif-production/16-Pre-Cancer-Atlas-for-Melanoma/PCAII_p16_e24/mcmicro_done/13Cycles/LSP11395/registration/LSP11395.ome.tif"
LSP11467 = "Y:/cycif-production/16-Pre-Cancer-Atlas-for-Melanoma/PCAII_p16_e24/mcmicro_done/13Cycles/LSP11467/registration/LSP11467.ome.tif"
LSP12422 = "Y:/cycif-production/16-Pre-Cancer-Atlas-for-Melanoma/PCAII_p16_e24/mcmicro_done/13Cycles/LSP12422/registration/LSP12422.ome.tif"
LSP11643 = "Y:/cycif-production/16-Pre-Cancer-Atlas-for-Melanoma/PCAII_p16_e24/mcmicro_done/13Cycles/LSP11643/registration/LSP11643.ome.tif"
LSP11515 = "Y:/cycif-production/16-Pre-Cancer-Atlas-for-Melanoma/PCAII_p16_e24/mcmicro_done/13Cycles/LSP11515/registration/LSP11515.ome.tif"

# %%
#list of all markers in the CYCIF image
all_markers = ['DNA1','MART1','CD207','SOX10','DNA2','GZMB','CD163','CD1c','KRT14','DNA3','CD3e','CD11c','CD8a','aSMA','DNA4','CD20',
           'CD68','PDL1','DNA5','MITF','FOXP3','PD1','panCK','DNA6','CD16','CD206','CD31','Vim','DNA7','S100A','LAG3','CD56',
           'pS6','DNA8','HLA-A/B','SOX9','HLA-DPB1','PCNA','DNA9','CD14','CD66b','CD45','pH3','DNA10','LMNB2','Nestin',
           'H3K27Me3','DNA11','PRAME','TIGIT','TIM3','DNA12','CD57','cPARP','Ki67_1','DNA13','CD4','Ki67_2','IRF1']


sm.pl.image_viewer(image_path = LSP11315, adata=adata2, overlay='spatial_cluster_RCNG', 
                   channel_names=all_markers, x_coordinate='X_centroid', y_coordinate='Y_centroid', 
                   point_size=30, subset='MEL14', imageid='MELid')

# %%
adata2.obs.SOM_branch_ID.value_counts()
# Out:
# SOM_branch_ID
# Other           898764
# branch1          42396
# branch3          34467
# LSP13135_029      3292
# LSP13165_007      3108
#                  ...
# LSP13140_003        20
# LSP13145_003        11
# LSP13145_018        10
# LSP13140_024         5
# LSP13135_043         3
# Name: count, Length: 250, dtype: int64

# %%
rename={'Epidermis':['0','23','7'],
        'Epidermis_MIS':['5'],
        'Tumor-stroma':['13'],
        'Tumor':['21','2'],
        'T_cell':['3','15','4','16'],
        'CD8+ T cell':['10'],
        'Exhausted CTL':['11'],
        'Perivascular T cells':['18'],
        'Vasculature':['24','17','22','1'],
        'Myeloid/macrophage':['8','19','20','12'],
        'Mixed_immune/stroma':['14','6','9']}
adata2 = sm.hl.rename(adata2, rename, from_column='spatial_cluster_kmeans_25', to_column='spatial_cluster_renamed')
# Out:
# Renaming 0 to Epidermis
# Renaming 23 to Epidermis
# Renaming 7 to Epidermis
# Renaming 5 to Epidermis_MIS
# Renaming 13 to Tumor-stroma
# Renaming 21 to Tumor
# Renaming 2 to Tumor
# Renaming 3 to T_cell
# Renaming 15 to T_cell
# Renaming 4 to T_cell
# Renaming 16 to T_cell
# Renaming 10 to CD8+ T cell
# Renaming 11 to Exhausted CTL
# Renaming 18 to Perivascular T cells
# Renaming 24 to Vasculature
# Renaming 17 to Vasculature
# Renaming 22 to Vasculature
# Renaming 1 to Vasculature
# Renaming 8 to Myeloid/macrophage
# Renaming 19 to Myeloid/macrophage
# Renaming 20 to Myeloid/macrophage
# Renaming 12 to Myeloid/macrophage
# Renaming 14 to Mixed_immune/stroma
# Renaming 6 to Mixed_immune/stroma
# Renaming 9 to Mixed_immune/stroma

# %%
rename={'RCNG1':['Tumor'],
        'RCNG2':['Tumor-stroma'],
        'RCNG3':['Epidermis_MIS'],
        'RCNG4':['Epidermis'],
        'RCNG5':['T_cell'],
        'RCNG6':['Perivascular T cells'],
        'RCNG7':['Myeloid/macrophage'],
        'RCNG8':['Exhausted CTL'],
        'RCNG9':['Mixed_immune/stroma'],
        'RCNG10':['CD8+ T cell'],
        'RCNG11':['Vasculature']}
adata2 = sm.hl.rename(adata2, rename, from_column='spatial_cluster_renamed', to_column='spatial_cluster_RCNG')
# Out:
# Renaming Tumor to RCNG1
# Renaming Tumor-stroma to RCNG2
# Renaming Epidermis_MIS to RCNG3
# Renaming Epidermis to RCNG4
# Renaming T_cell to RCNG5
# Renaming Perivascular T cells to RCNG6
# Renaming Myeloid/macrophage to RCNG7
# Renaming Exhausted CTL to RCNG8
# Renaming Mixed_immune/stroma to RCNG9
# Renaming CD8+ T cell to RCNG10
# Renaming Vasculature to RCNG11

# %%
## RCNG composition in Branch1 and Branch 3

# %%
mel=['branch1','branch3']
test=adata2[(adata2.obs['SOM_branch_ID'].isin(mel))]

# %%
branch1=['LSP13987_014','LSP13987_012','LSP13987_017','LSP13947_001','LSP13996_001','LSP13943_004','LSP13987_013','LSP13987_007','LSP13987_011','LSP13996_003','LSP13987_005','LSP13987_008','LSP13947_010','LSP13987_004','LSP13987_009','LSP13985_004','LSP13947_009','LSP13985_002','LSP13985_001','LSP13987_003','LSP13947_014','LSP13947_017','LSP13947_004','LSP13947_018','LSP13987_016','LSP13996_005','LSP13947_008','LSP13985_003','LSP13947_006','LSP13947_007','LSP13987_006','LSP13996_002','LSP13987_001','LSP13947_005','LSP13987_002']

customColors ={'RCNG1' : '#D52928',
               'RCNG2' : '#8E0000',
               'RCNG3' : '#BC714A',
               'RCNG4':'#A7A9AC',
               'RCNG5':'#2B3990',
               'RCNG6':'#FFF800',
               'RCNG7':'#8DC63F',
               'RCNG8':'#8D00C1',
               'RCNG9':'#F7941D',
              'RCNG10':'#FF00ED',
              'RCNG11':'#27AAE1'}

x=['LSP13987_014','LSP13987_012','LSP13987_017','LSP13947_001','LSP13996_001','LSP13943_004','LSP13987_013','LSP13987_007','LSP13987_011','LSP13996_003','LSP13987_005','LSP13987_008','LSP13947_010','LSP13987_004','LSP13987_009','LSP13985_004','LSP13947_009','LSP13985_002','LSP13985_001','LSP13987_003','LSP13947_014','LSP13947_017','LSP13947_004','LSP13947_018','LSP13987_016','LSP13996_005','LSP13947_008','LSP13985_003','LSP13947_006','LSP13947_007','LSP13987_006','LSP13996_002','LSP13987_001','LSP13947_005','LSP13987_002','LSP13943_008','LSP13943_013','LSP13943_005','LSP13943_006','LSP13943_009','LSP13943_016','LSP13943_015','LSP13985_008','LSP13943_007','LSP13985_013','LSP13943_003','LSP13943_002','LSP13943_012','LSP13943_011','LSP13985_010','LSP13943_014','LSP13985_014','LSP13985_012','LSP13985_009']
test_data=sm.pl.stacked_barplot(test, x_axis='ROI_GeoMX', y_axis='spatial_cluster_RCNG', 
                      subset_xaxis=branch1, subset_yaxis=None, order_xaxis=branch1, order_yaxis=None, figsize=(8,2.5), method='percent',
                     color=customColors,return_data=True)
test_data=test_data.sort_values(by='RCNG1', ascending=False) 
order = list(test_data.index)

sm.pl.stacked_barplot(test, x_axis='ROI_GeoMX', y_axis='spatial_cluster_RCNG', 
                      subset_xaxis=branch1, subset_yaxis=None, order_xaxis=order, order_yaxis=None, figsize=(8,2.5), method='percent',
                     return_data=False, color=customColors, fileName="RCNG_composition_in_branch1.pdf", saveDir=(r"C:\Users\tav9\HMS Dropbox\Tuulia Vallius\test\test"))
# Out:
# C:\Users\tav9\AppData\Local\anaconda3\envs\scimap_new\lib\site-packages\scimap\plotting\stacked_barplot.py:197: UserWarning:
#
# 'color' and 'colormap' cannot be used simultaneously. Using 'color'
# C:\Users\tav9\AppData\Local\anaconda3\envs\scimap_new\lib\site-packages\scimap\plotting\stacked_barplot.py:197: UserWarning:
#
# 'color' and 'colormap' cannot be used simultaneously. Using 'color'
# Saved plot to C:\Users\tav9\HMS Dropbox\Tuulia Vallius\test\test\RCNG_composition_in_branch1.pdf

# %%
branch3=['LSP13943_008','LSP13943_013','LSP13943_005','LSP13943_006','LSP13943_009','LSP13943_016','LSP13943_015','LSP13985_008','LSP13943_007','LSP13985_013','LSP13943_003','LSP13943_002','LSP13943_012','LSP13943_011','LSP13985_010','LSP13943_014','LSP13985_014','LSP13985_012','LSP13985_009']
customColors ={'RCNG1' : '#D52928',
               'RCNG2' : '#8E0000',
               'RCNG3' : '#BC714A',
               'RCNG4':'#A7A9AC',
               'RCNG5':'#2B3990',
               'RCNG6':'#FFF800',
               'RCNG7':'#8DC63F',
               'RCNG8':'#8D00C1',
               'RCNG9':'#F7941D',
              'RCNG10':'#FF00ED',
              'RCNG11':'#27AAE1'}
test_data=sm.pl.stacked_barplot(test, x_axis='ROI_GeoMX', y_axis='spatial_cluster_RCNG', 
                      subset_xaxis=branch3, subset_yaxis=None, order_xaxis=branch3, order_yaxis=None, figsize=(4,2.5), method='percent',
                     color=customColors,return_data=True)
test_data=test_data.sort_values(by='RCNG1', ascending=False) 
order = list(test_data.index)

sm.pl.stacked_barplot(test, x_axis='ROI_GeoMX', y_axis='spatial_cluster_RCNG', 
                      subset_xaxis=branch3, subset_yaxis=None, order_xaxis=order, order_yaxis=None, figsize=(4,2.5), method='percent',
                     return_data=False, color=customColors, fileName="RCNG_composition_in_branch3.pdf", saveDir=(r"C:\Users\tav9\HMS Dropbox\Tuulia Vallius\test\test"))
# Out:
# C:\Users\tav9\AppData\Local\anaconda3\envs\scimap_new\lib\site-packages\scimap\plotting\stacked_barplot.py:197: UserWarning:
#
# 'color' and 'colormap' cannot be used simultaneously. Using 'color'
# C:\Users\tav9\AppData\Local\anaconda3\envs\scimap_new\lib\site-packages\scimap\plotting\stacked_barplot.py:197: UserWarning:
#
# 'color' and 'colormap' cannot be used simultaneously. Using 'color'
# Saved plot to C:\Users\tav9\HMS Dropbox\Tuulia Vallius\test\test\RCNG_composition_in_branch3.pdf

# %%
df=test.to_df(layer=None)
df['SOM_branch_ID']=test.obs['SOM_branch_ID']
df['spatial_cluster_RCNG']=test.obs['spatial_cluster_RCNG']
df['MELid']=test.obs['MELid']
df['ROI_GeoMX']=test.obs['ROI_GeoMX']

# %%
df
# Out:
#                                   DNA1     MART1     CD207     SOX10  \
# unmicst-LSP11523_cell_509     0.632978  0.848112  0.322840  0.497011
# unmicst-LSP11523_cell_513     0.583331  0.836078  0.297870  0.470041
# unmicst-LSP11523_cell_518     0.714360  0.636200  0.212647  0.352207
# unmicst-LSP11523_cell_519     0.748036  0.810490  0.302336  0.366127
# unmicst-LSP11523_cell_521     0.581054  0.909051  0.343995  0.511392
# ...                                ...       ...       ...       ...
# unmicst-LSP11643_cell_104687  0.666688  0.569960  0.385397  0.477197
# unmicst-LSP11643_cell_104704  0.648048  0.611084  0.393118  0.606728
# unmicst-LSP11643_cell_104714  0.606206  0.595962  0.388824  0.598053
# unmicst-LSP11643_cell_104728  0.592642  0.578535  0.389099  0.573458
# unmicst-LSP11643_cell_104733  0.604724  0.637006  0.399402  0.654929
#
#                                   GZMB     CD163      CD1c     KRT14  \
# ...

# %%
grouped_data1=df.groupby(['ROI_GeoMX','spatial_cluster_RCNG'], group_keys=False).agg({'spatial_cluster_RCNG':'count'})
group=grouped_data1.groupby(level=0).apply(lambda x: 100*x / float(x.sum()))
# Out:
# C:\Users\tav9\AppData\Local\Temp\ipykernel_45524\2182407354.py:1: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# C:\Users\tav9\AppData\Local\Temp\ipykernel_45524\2182407354.py:2: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# C:\Users\tav9\AppData\Local\Temp\ipykernel_45524\2182407354.py:2: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead

# %%
group
# Out:
#                                                 spatial_cluster_RCNG
# ROI_GeoMX    ROI_GeoMX    spatial_cluster_RCNG
# LSP13943_002 LSP13943_002 RCNG1                            21.739130
#                           RCNG10                            0.000000
#                           RCNG11                            0.683230
#                           RCNG2                             4.658385
#                           RCNG3                            20.434783
# ...                                                              ...
# undefined    undefined    RCNG5                             2.604167
#                           RCNG6                             1.591435
#                           RCNG7                             1.649306
#                           RCNG8                             6.278935
#                           RCNG9                             4.542824
#
# [605 rows x 1 columns]

# %%
group.to_csv(r"C:\Users\tav9\HMS Dropbox\Tuulia Vallius\test\test\testgroup1.csv")

# %%
group_df = pd.read_csv(r"C:\Users\tav9\HMS Dropbox\Tuulia Vallius\test\test\testgroup1.csv")

# %%
branch1=['LSP13987_011','LSP13987_012','LSP13987_013','LSP13987_014','LSP13987_016','LSP13987_017','LSP13968_003','LSP13968_004','LSP13968_005','LSP13968_007','LSP13968_009','LSP13968_010','LSP13968_012','LSP13968_019','LSP13968_030','LSP13968_036','LSP13968_037','LSP13975_015','LSP13975_023','LSP13975_024','LSP13975_028','LSP13975_029','LSP13975_030','LSP13975_031','LSP13987_001','LSP13987_002','LSP13987_003','LSP13987_004','LSP13987_005','LSP13987_006','LSP13987_007','LSP13987_008','LSP13987_009','LSP13987_010','LSP13939_023','LSP13939_024','LSP13939_025','LSP13939_026','LSP13939_027','LSP13939_028','LSP13939_029','LSP13943_004','LSP13932_020','LSP13932_023','LSP13947_001','LSP13947_004','LSP13947_005','LSP13947_006','LSP13947_007','LSP13947_008','LSP13947_009','LSP13947_010','LSP13947_014','LSP13947_015','LSP13947_017','LSP13947_018','LSP13996_001','LSP13996_002','LSP13996_003','LSP13996_005','LSP13985_001','LSP13985_002','LSP13985_003','LSP13985_004','LSP13961_023','LSP13961_024','LSP13961_025','LSP13961_028','LSP13961_030','LSP13961_031','LSP13961_032','LSP13961_034','LSP13914_005','LSP13914_006','LSP13914_007','LSP13914_008','LSP13914_009','LSP13914_011','LSP13914_012','LSP13914_014','LSP13914_015','LSP13914_017','LSP13918_006','LSP13918_007','LSP13918_029','LSP13918_041','LSP13918_043','LSP13918_045']
branch3=['LSP13968_001','LSP13968_002','LSP13968_015','LSP13968_017','LSP13968_027','LSP13968_031','LSP13968_033','LSP13968_034','LSP13968_038','LSP13975_003','LSP13975_008','LSP13975_009','LSP13975_018','LSP13975_020','LSP13975_021','LSP13975_022','LSP13925_005','LSP13925_006','LSP13925_007','LSP13925_008','LSP13925_013','LSP13925_020','LSP13925_021','LSP13925_023','LSP13925_024','LSP13925_025','LSP13925_027','LSP13925_029','LSP13925_030','LSP13939_003','LSP13939_004','LSP13939_005','LSP13939_006','LSP13939_007','LSP13939_008','LSP13939_011','LSP13939_012','LSP13939_014','LSP13939_015','LSP13939_016','LSP13939_018','LSP13943_002','LSP13943_003','LSP13943_005','LSP13943_006','LSP13943_007','LSP13943_008','LSP13943_009','LSP13943_011','LSP13943_012','LSP13943_013','LSP13943_014','LSP13943_015','LSP13943_016','LSP13932_003','LSP13932_004','LSP13932_006','LSP13996_012','LSP13996_013','LSP13996_014','LSP13996_016','LSP13996_017','LSP13996_019','LSP13996_021','LSP13985_008','LSP13985_009','LSP13985_010','LSP13985_012','LSP13985_013','LSP13985_014','LSP13961_004','LSP13961_005','LSP13961_006','LSP13961_007','LSP13961_008','LSP13961_009','LSP13961_010','LSP13961_011','LSP13961_035','LSP13918_028','LSP13918_030','LSP13918_031','LSP13918_035','LSP13918_042','LSP13954_001','LSP13954_002','LSP13954_003','LSP13954_004','LSP13954_005','LSP13954_006','LSP13954_007','LSP13954_008','LSP13954_010','LSP13954_011','LSP13954_012','LSP13954_013','LSP13954_014']
group_df = group_df.assign(Branch_ID = lambda x: x.ROI_GeoMX.isin(branch1))
group_df['Branch_ID'] = group_df['Branch_ID'].replace({True: 'branch1', False: 'branch3'})

# %%
group_df
# Out:
#         ROI_GeoMX   ROI_GeoMX.1 spatial_cluster_RCNG  spatial_cluster_RCNG.1  \
# 0    LSP13943_002  LSP13943_002                RCNG1               21.739130
# 1    LSP13943_002  LSP13943_002               RCNG10                0.000000
# 2    LSP13943_002  LSP13943_002               RCNG11                0.683230
# 3    LSP13943_002  LSP13943_002                RCNG2                4.658385
# 4    LSP13943_002  LSP13943_002                RCNG3               20.434783
# ..            ...           ...                  ...                     ...
# 600     undefined     undefined                RCNG5                2.604167
# 601     undefined     undefined                RCNG6                1.591435
# 602     undefined     undefined                RCNG7                1.649306
# 603     undefined     undefined                RCNG8                6.278935
# 604     undefined     undefined                RCNG9                4.542824
#
#     Branch_ID
# 0     branch3
# ...

# %%
plt.rcParams["figure.figsize"] = (4,3)

sns.stripplot(data=group_df, x="spatial_cluster_RCNG", y="spatial_cluster_RCNG.1", hue="Branch_ID", hue_order=['branch1','branch3'], 
              order=['RCNG11', 'RCNG7','RCNG10','RCNG8','RCNG3','RCNG4','RCNG1','RCNG2','RCNG5','RCNG6','RCNG9'], legend=False, dodge=True, color='black', s=1)
ax=sns.boxplot(data=group_df, x='spatial_cluster_RCNG', y='spatial_cluster_RCNG.1', hue='Branch_ID',hue_order=['branch1','branch3'], 
               order=['RCNG11', 'RCNG7','RCNG10','RCNG8','RCNG3','RCNG4','RCNG1','RCNG2','RCNG5','RCNG6','RCNG9'], palette=['red','dodgerblue'],fill=True, gap=.1,fliersize=1)
ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
plt.savefig("C:/Users/tav9/Dropbox (HMS)/test/test/spatial_cluster_RCNG_branch_status_05282025.pdf")
# Out:
# C:\Users\tav9\AppData\Local\Temp\ipykernel_45524\3325865357.py:3: FutureWarning:
#
#
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:black'` for the same effect.
#
#
# C:\Users\tav9\AppData\Local\Temp\ipykernel_45524\3325865357.py:7: UserWarning:
#
# set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.

# %%
import scipy.stats as stats

# %%
#significant ones: RCNG3, 4, 7,8, 10, 11 --> order 11, 7,  10, 8, 3, 4, 

group1=group_df[group_df['Branch_ID']=='branch1']
group2=group_df[group_df['Branch_ID']=='branch3']

group1=group1[group1['spatial_cluster_RCNG']=='RCNG4']
group2=group2[group2['spatial_cluster_RCNG']=='RCNG4']

statistic, p_value = stats.mannwhitneyu(group1['spatial_cluster_RCNG.1'],group2['spatial_cluster_RCNG.1'])
print("p-value=",p_value)
# Out:
# p-value= 0.048740716131747845

# %%
## spatial scatter plots

# %%
customColors ={'RCNG1' :'#D52928',
               'RCNG2' :'#8E0000',
               'RCNG3' :'#BC714A',
               'RCNG4':'#A7A9AC',
               'RCNG5':'#2B3990',
               'RCNG6':'#FFF800',
               'RCNG7':'#8DC63F',
               'RCNG8':'#8D00C1',
               'RCNG9':'#F7941D',
              'RCNG10':'#FF00ED',
              'RCNG11':'#27AAE1'}



mel=['MEL14']
MEL14=adata2[(adata2.obs['MELid'].isin(mel))]

tmp = MEL14[MEL14.obs['Y_centroid'] > 15000 ]
tmp = tmp[tmp.obs['Y_centroid'] < 30000 ]

#tmp = tmp[tmp.obs['X_centroid'] < 27000 ]
tmp = tmp[tmp.obs['X_centroid'] > 43000 ]

sm.pl.spatial_scatterPlot(adata=tmp, colorBy=['spatial_cluster_RCNG'], x_coordinate='X_centroid', 
                          y_coordinate='Y_centroid',customColors=customColors,
                          imageid='MELid', layer=None, subset='MEL14', s=2, figsize=(4,6),fileName='MEL14_RCNG_exemplaryregion.png', saveDir='C:/Users/tav9/Dropbox (HMS)/test/test/')
# Out:
# Saved plot to C:/Users/tav9/Dropbox (HMS)/test/test/MEL14_RCNG_exemplaryregion.png

# %%
MEL14
# Out:
# View of AnnData object with n_obs × n_vars = 96420 × 46
#     obs: 'X_centroid', 'Y_centroid', 'Area', 'MajorAxisLength', 'MinorAxisLength', 'Eccentricity', 'Solidity', 'Extent', 'Orientation', 'CellID', 'imageid', 'ROI', 'ROI_major_category', 'ROI_minor_category', 'phenotype', 'phenotype_v2', 'MELid', 'PCNApos', 'KI67pos', 'MARTpos', 'lineage', 'lineage_grouped', 'lose_08032023', 'proliferation', 'proliferation2', 'prolif2_lineage', 'imageid_raw', 'MART1pos', 'spatial_cluster_kmeans_25', 'spatial_cluster_grouped', 'index_col', 'ROI_GeoMX', 'SOM_branch_ID', 'spatial_cluster_renamed', 'spatial_cluster_RCNG'
#     uns: 'all_markers', 'gates', 'lineage_colors', 'spatial_count_MART', 'spatial_distance_MART'

# %%
a=MEL14.to_df()
a['CellID']=MEL14.obs['CellID']
a['spatial_cluster_RCNG']=MEL14.obs['spatial_cluster_RCNG']
a['X_centroid']=MEL14.obs['X_centroid']
a['Y_centroid']=MEL14.obs['Y_centroid']

# %%
a.to_csv(r"C:\Users\tav9\HMS Dropbox\Tuulia Vallius\2024-Vallius-Novikov-Shi-Melanoma_PCA\data\e24\RCN\MEL14_RCNG_data.csv")

# %%
customColors ={'RCNG1' : '#D52928',
               'RCNG2' : '#8E0000',
               'RCNG3' : '#BC714A',
               'RCNG4':'#A7A9AC',
               'RCNG5':'#2B3990',
               'RCNG6':'#FFF800',
               'RCNG7':'#8DC63F',
               'RCNG8':'#8D00C1',
               'RCNG9':'#F7941D',
              'RCNG10':'#FF00ED',
              'RCNG11':'#27AAE1'}



mel=['MEL54']
MEL54=adata2[(adata2.obs['MELid'].isin(mel))]

tmp = MEL54[MEL54.obs['Y_centroid'] > 25000 ]
tmp = tmp[tmp.obs['Y_centroid'] < 45000 ]

tmp = tmp[tmp.obs['X_centroid'] > 45000 ]
tmp = tmp[tmp.obs['X_centroid'] < 60000 ]

sm.pl.spatial_scatterPlot(adata=tmp, colorBy=['spatial_cluster_RCNG'], x_coordinate='X_centroid', 
                          y_coordinate='Y_centroid',customColors=customColors,
                          imageid='MELid', layer=None, subset='MEL54', s=1, figsize=(4,5))

# %%
customColors ={'RCNG1' : '#D52928',
               'RCNG2' : '#8E0000',
               'RCNG3' : '#BC714A',
               'RCNG4':'#A7A9AC',
               'RCNG5':'#2B3990',
               'RCNG6':'#FFF800',
               'RCNG7':'#8DC63F',
               'RCNG8':'#8D00C1',
               'RCNG9':'#F7941D',
              'RCNG10':'#FF00ED',
              'RCNG11':'#27AAE1'}



mel=['MEL23']
MEL23=adata2[(adata2.obs['MELid'].isin(mel))]

tmp = MEL23[MEL23.obs['Y_centroid'] > 10000 ]
tmp = tmp[tmp.obs['Y_centroid'] < 40000 ]

tmp = tmp[tmp.obs['X_centroid'] > 40000 ]
tmp = tmp[tmp.obs['X_centroid'] < 52000 ]

sm.pl.spatial_scatterPlot(adata=tmp, colorBy=['spatial_cluster_RCNG'], x_coordinate='X_centroid', 
                          y_coordinate='Y_centroid',customColors=customColors,
                          imageid='MELid', layer=None, subset='MEL23', s=1, figsize=(4,7),dpi=600,fileName='MEL23_RCNG_exemplaryregion.png', saveDir='C:/Users/tav9/Dropbox (HMS)/test/test/')
# Out:
# Saved plot to C:/Users/tav9/Dropbox (HMS)/test/test/MEL23_RCNG_exemplaryregion.png

# %%
## RCNG change over progression

# %%
roi=['VGP','MIS','RGP','precursor','normal']
order=['normal','precursor','MIS','RGP','VGP']
ROI=adata2[(adata2.obs['ROI_major_category'].isin(roi))]
a=sm.pl.stacked_barplot(ROI, y_axis='spatial_cluster_RCNG', x_axis='ROI_major_category', 
                      subset_xaxis=None, subset_yaxis=None, order_xaxis=order, order_yaxis=None, matplotlib_cmap='tab20',
                      method='percent', return_data=True)

# %%
a
# Out:
# spatial_cluster_RCNG     RCNG1    RCNG10    RCNG11     RCNG2     RCNG3  \
# ROI_major_category
# MIS                   0.105794  0.013548  0.085566  0.040713  0.110151
# RGP                   0.082810  0.054652  0.086936  0.044241  0.073264
# VGP                   0.257620  0.038124  0.089749  0.101946  0.021891
# normal                0.004313  0.002027  0.174674  0.000690  0.008712
# precursor             0.011676  0.003280  0.139414  0.005615  0.022267
#
# spatial_cluster_RCNG     RCNG4     RCNG5     RCNG6     RCNG7     RCNG8  \
# ROI_major_category
# MIS                   0.290256  0.134887  0.027257  0.105890  0.016985
# RGP                   0.208437  0.223254  0.036411  0.102527  0.015761
# VGP                   0.063887  0.192689  0.032643  0.111162  0.029567
# normal                0.632149  0.019667  0.012378  0.037911  0.000431
# precursor             0.609585  0.046925  0.021433  0.042311  0.003225
#
# spatial_cluster_RCNG     RCNG9
# ROI_major_category
# ...

# %%
sns.lineplot(data=a, dashes=False)
plt.savefig("C:/Users/tav9/Dropbox (HMS)/test/test/RCNG_ROI_categories.pdf")

# %%
## RCNGs in Breslow groups

# %%
rename={'<1mm':['MEL36','MEL16','MEL66','MEL17','MEL40','MEL33','MEL60','MEL52','MEL56','MEL50','MEL15','MEL21','MEL38','MEL42','MEL44','MEL53','MEL26','MEL49'],
        '1-2mm':['MEL23','MEL25','MEL51','MEL64','MEL45','MEL14','MEL19','MEL68','MEL24','MEL27','MEL18','MEL69','MEL65','MEL48','MEL47','MEL54','MEL86','MEL59'],
        '2-4mm':['MEL20','MEL81','MEL85','MEL78','MEL73','MEL77','MEL80','MEL76','MEL84','MEL58','MEL55']}
adata = sm.hl.rename(adata2, rename, from_column='MELid', to_column='Breslow')
# Out:
# Renaming MEL36 to <1mm
# Renaming MEL16 to <1mm
# Renaming MEL66 to <1mm
# Renaming MEL17 to <1mm
# Renaming MEL40 to <1mm
# Renaming MEL33 to <1mm
# Renaming MEL60 to <1mm
# Renaming MEL52 to <1mm
# Renaming MEL56 to <1mm
# Renaming MEL50 to <1mm
# Renaming MEL15 to <1mm
# Renaming MEL21 to <1mm
# Renaming MEL38 to <1mm
# Renaming MEL42 to <1mm
# Renaming MEL44 to <1mm
# Renaming MEL53 to <1mm
# Renaming MEL26 to <1mm
# Renaming MEL49 to <1mm
# Renaming MEL23 to 1-2mm
# Renaming MEL25 to 1-2mm
# Renaming MEL51 to 1-2mm
# Renaming MEL64 to 1-2mm
# Renaming MEL45 to 1-2mm
# Renaming MEL14 to 1-2mm
# Renaming MEL19 to 1-2mm
# Renaming MEL68 to 1-2mm
# Renaming MEL24 to 1-2mm
# Renaming MEL27 to 1-2mm
# Renaming MEL18 to 1-2mm
# Renaming MEL69 to 1-2mm
# Renaming MEL65 to 1-2mm
# Renaming MEL48 to 1-2mm
# Renaming MEL47 to 1-2mm
# Renaming MEL54 to 1-2mm
# Renaming MEL86 to 1-2mm
# Renaming MEL59 to 1-2mm
# Renaming MEL20 to 2-4mm
# Renaming MEL81 to 2-4mm
# Renaming MEL85 to 2-4mm
# ...

# %%
df=adata2.to_df(layer=None)
df['SOM_branch_ID']=adata2.obs['SOM_branch_ID']
df['spatial_cluster_RCNG']=adata2.obs['spatial_cluster_RCNG']
df['MELid']=adata2.obs['MELid']
df['ROI_GeoMX']=adata2.obs['ROI_GeoMX']
df['Breslow']=adata2.obs['Breslow']

# %%
def calculate_proportions(df, celltype, location_col, sample_col):
    """Calculates the proportions of a given cell type in different locations for each sample.

    Args:
        df: The input pandas DataFrame.
        celltype: The cell type to analyze.
        location_col: The name of the column containing location information.
        sample_col: The name of the column containing sample ID information.

    Returns:
        A pandas DataFrame containing the calculated proportions.
    """

    # Filter the DataFrame for the specified cell type
    filtered_df = df[df["Breslow"] == celltype]

    # Group by location and sample, count occurrences, and calculate proportions
    proportions_df = filtered_df.groupby([location_col, sample_col]).size().reset_index(name="count")
    proportions_df["proportion"] = proportions_df["count"] / proportions_df.groupby(sample_col)["count"].transform("sum")

    return proportions_df


proportions_df_less_than_1mm=calculate_proportions(df=df, celltype='<1mm', location_col='spatial_cluster_RCNG', sample_col='MELid')
# Out:
# C:\Users\tav9\AppData\Local\Temp\ipykernel_45524\1413751739.py:18: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# C:\Users\tav9\AppData\Local\Temp\ipykernel_45524\1413751739.py:19: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.

# %%
proportions_df_less_than_1mm
# Out:
#     spatial_cluster_RCNG  MELid  count  proportion
# 0                  RCNG1  MEL14      0         NaN
# 1                  RCNG1  MEL17   1203    0.115241
# 2                  RCNG1  MEL18      0         NaN
# 3                  RCNG1  MEL19      0         NaN
# 4                  RCNG1  MEL23      0         NaN
# ..                   ...    ...    ...         ...
# 215                RCNG9  MEL52   5102    0.123877
# 216                RCNG9  MEL54      0         NaN
# 217                RCNG9  MEL56   2349    0.150077
# 218                RCNG9  MEL58      0         NaN
# 219                RCNG9  MEL65      0         NaN
#
# [220 rows x 4 columns]

# %%
imageid=['MEL36','MEL16','MEL66','MEL17','MEL40','MEL33','MEL60','MEL52','MEL56','MEL50','MEL15','MEL21','MEL38','MEL42','MEL44','MEL53','MEL26','MEL49','MEL23','MEL25','MEL51','MEL64','MEL45','MEL14','MEL19','MEL68','MEL24','MEL27','MEL18','MEL69','MEL65','MEL48','MEL47','MEL54','MEL86','MEL59','MEL20','MEL81','MEL85','MEL78','MEL73','MEL77','MEL80','MEL76','MEL84','MEL58','MEL55']

def apply_status(image_id):
    if image_id in imageid:
        return 'less_than_1mm'   

proportions_df_less_than_1mm['Breslow']=proportions_df_less_than_1mm['MELid'].apply(apply_status)
proportions_df_less_than_1mm.dropna(axis=0, inplace=True)

# %%
proportions_df_1_2mm=calculate_proportions(df=df, celltype='1-2mm', location_col='spatial_cluster_RCNG', sample_col='MELid')
# Out:
# C:\Users\tav9\AppData\Local\Temp\ipykernel_45524\1413751739.py:18: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# C:\Users\tav9\AppData\Local\Temp\ipykernel_45524\1413751739.py:19: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.

# %%
proportions_df_1_2mm
# Out:
#     spatial_cluster_RCNG  MELid  count  proportion
# 0                  RCNG1  MEL14   3128    0.032441
# 1                  RCNG1  MEL17      0         NaN
# 2                  RCNG1  MEL18   7227    0.066761
# 3                  RCNG1  MEL19  16259    0.294270
# 4                  RCNG1  MEL23  22874    0.125285
# ..                   ...    ...    ...         ...
# 215                RCNG9  MEL52      0         NaN
# 216                RCNG9  MEL54   6989    0.105952
# 217                RCNG9  MEL56      0         NaN
# 218                RCNG9  MEL58      0         NaN
# 219                RCNG9  MEL65   1666    0.071484
#
# [220 rows x 4 columns]

# %%
def apply_status(image_id):
    if image_id in imageid:
        return '1_2mm'   

proportions_df_1_2mm['Breslow']=proportions_df_1_2mm['MELid'].apply(apply_status)
proportions_df_1_2mm.dropna(axis=0, inplace=True)

# %%
frames=[proportions_df_less_than_1mm,proportions_df_1_2mm]
merged_df_3=pd.concat(frames)

# %%
ax=sns.stripplot(data=merged_df_3, x="spatial_cluster_RCNG", y="proportion", hue="Breslow", 
               order=['RCNG11', 'RCNG7','RCNG10','RCNG8','RCNG3','RCNG4','RCNG1','RCNG2','RCNG5','RCNG6','RCNG9'], 
                 legend=False, dodge=True, color='black', s=2)
ax=sns.boxplot(data=merged_df_3, x="spatial_cluster_RCNG", y="proportion", hue="Breslow", fliersize=1, 
               order=['RCNG11', 'RCNG7','RCNG10','RCNG8','RCNG3','RCNG4','RCNG1','RCNG2','RCNG5','RCNG6','RCNG9'],
               palette=['#DC86B6','#DCD425'])
ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
plt.savefig("C:/Users/tav9/Dropbox (HMS)/test/test/spatial_cluster_RCNG_Breslow_v2.pdf")
# Out:
# C:\Users\tav9\AppData\Local\Temp\ipykernel_45524\2133880649.py:1: FutureWarning:
#
#
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:black'` for the same effect.
#
#
# C:\Users\tav9\AppData\Local\Temp\ipykernel_45524\2133880649.py:7: UserWarning:
#
# set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.

# %%
group1=merged_df_3[merged_df_3['Breslow']=='less_than_1mm']
group2=merged_df_3[merged_df_3['Breslow']=='1_2mm']

group1=group1[group1['spatial_cluster_RCNG']=='RCNG9']
group2=group2[group2['spatial_cluster_RCNG']=='RCNG9']

statistic, p_value = stats.mannwhitneyu(group1['proportion'],group2['proportion'])
print("p-value=",p_value)
# Out:
# p-value= 0.37493715434891906
