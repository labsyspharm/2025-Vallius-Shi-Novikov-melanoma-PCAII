# %%
import numpy as np
import pandas as pd
import scanpy
import anndata as ad

import seaborn as sns; sns.set(color_codes=True); sns.set_style("whitegrid"); 
from matplotlib import pyplot as plt
plt.rcParams["axes.grid"] = False

import networkx as nx
from scipy.spatial import Delaunay
import copy

# %%
adata = scanpy.read_h5ad('/Users/ediknovik/Dropbox/Harvard-University/Sorger-HMS-Postdoc/PCA-Melanoma-Analysis/data/pca_stage2_samples/p135_e9_adtumorV5_TV.h5ad')
adata
# Out:
# AnnData object with n_obs × n_vars = 1757421 × 39
#     obs: 'X_centroid', 'Y_centroid', 'Area', 'MajorAxisLength', 'MinorAxisLength', 'Eccentricity', 'Solidity', 'Extent', 'Orientation', 'CellID', 'imageid', 'remove', 'case_split', 'KEEP', 'LOSE', 'MART1class', 'MART1pos', 'phenotypev2', 'imageid_rename', 'contiguous_spatial', 'case', 'simplified_phenotype', 'geomx_aoi', 'phenotype_all', 'geomx_aoi_cluster_ID', 'morphology', 'combined_hist', 'recurrence'
#     uns: 'all_markers'
#     layers: 'log'

# %%
adata.obs.simplified_phenotype.unique()
# Out:
# ['SOX9-NGFR+', 'SOX9-NGFR-MART1-', 'SOX9-NGFR-MART1+', 'SOX9+NGFR-MART1+', 'SOX9+NGFR-MART1-', 'SOX9+NGFR+', 'SOX10-SOX9+']
# Categories (7, object): ['SOX9-NGFR+', 'SOX9-NGFR-MART1-', 'SOX9-NGFR-MART1+', 'SOX9+NGFR-MART1+', 'SOX9+NGFR-MART1-', 'SOX9+NGFR+', 'SOX10-SOX9+']

# %%
adata.obs.phenotypev2.unique()
# Out:
# ['SOX10+SOX9-NGFR+', 'SOX10+SOX9-NGFR-MART1-', 'SOX10+SOX9-NGFR-MART1+', 'SOX10+SOX9+NGFR-MART1+', 'SOX10+SOX9+NGFR-MART1-', 'SOX10+SOX9+NGFR+', 'SOX10-SOX9+']
# Categories (7, object): ['SOX10+SOX9-NGFR+', 'SOX10+SOX9-NGFR-MART1-', 'SOX10+SOX9-NGFR-MART1+', 'SOX10+SOX9+NGFR-MART1+', 'SOX10+SOX9+NGFR-MART1-', 'SOX10+SOX9+NGFR+', 'SOX10-SOX9+']

# %%
adata.obs.imageid.value_counts()
# Out:
# LSP15192      395382
# LSP15129      386373
# LSP13078      195251
# LSP13186      152263
# LSP15156      150588
# LSP15210      117755
# LSP13179      113798
# LSP15219_a     66053
# LSP15183       49993
# LSP15120       43214
# LSP15219_b     26588
# LSP13102       21478
# LSP15138       21405
# LSP15201       17280
# Name: imageid, dtype: int64

# %%
adata.obs.contiguous_spatial
# Out:
# LSP13102--unmicst_cellRing_65117-0-0      LSP13102_1
# LSP13102--unmicst_cellRing_65123-0-0      LSP13102_1
# LSP13102--unmicst_cellRing_65159-0-0      LSP13102_1
# LSP13102--unmicst_cellRing_65197-0-0      LSP13102_1
# LSP13102--unmicst_cellRing_65289-0-0      LSP13102_1
#                                              ...
# LSP15192--unmicst_cellRing_1133260-0-1    LSP15192_1
# LSP15192--unmicst_cellRing_1135617-0-1    LSP15192_1
# LSP15192--unmicst_cellRing_1136859-0-1    LSP15192_1
# LSP15192--unmicst_cellRing_1136908-0-1    LSP15192_1
# LSP15192--unmicst_cellRing_1136983-0-1    LSP15192_1
# Name: contiguous_spatial, Length: 1757421, dtype: category
# Categories (20, object): ['LSP13078_1', 'LSP13102_1', 'LSP13179_1', 'LSP13186_1', ..., 'LSP15219_a_2', 'LSP15219_b_1', 'LSP15219_b_2', 'Other']

# %%
# LSP15192 is the only sample that has a meaningful SOX10-SOX9+ population
adata[adata.obs.simplified_phenotype == 'SOX10-SOX9+'].obs.imageid.value_counts()
# Out:
# LSP15192    31440
# Name: imageid, dtype: int64

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 1757421 × 39
#     obs: 'X_centroid', 'Y_centroid', 'Area', 'MajorAxisLength', 'MinorAxisLength', 'Eccentricity', 'Solidity', 'Extent', 'Orientation', 'CellID', 'imageid', 'remove', 'case_split', 'KEEP', 'LOSE', 'MART1class', 'MART1pos', 'phenotypev2', 'imageid_rename', 'contiguous_spatial', 'case', 'simplified_phenotype', 'geomx_aoi', 'phenotype_all', 'geomx_aoi_cluster_ID', 'morphology', 'combined_hist', 'recurrence'
#     uns: 'all_markers'
#     layers: 'log'

# %%
### USE 7 classes for all samples when calculating spatial (check code) and nbhd (max_entropy) entropy. ### 
### look at average ECAD expression along the distance bands, maybe divided into 3 bands. Plot for each sample and if get a trend, combine for all samples and show together. ###
### GeoMX clusters - make heatmap across markers: already done, I think? ###

# %% [markdown]
# ### Check patient samples

# %%
for patient in adata.obs.contiguous_spatial.unique():
    if patient in ['Other']:
        continue
    data = adata[adata.obs.contiguous_spatial == patient]
    fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(10, 5))
    scanpy.pl.scatter(data,x='X_centroid',y='Y_centroid',color='simplified_phenotype', ax=ax, show=False)
    ax.set_title(f'Patient {patient}', fontsize=15)
# Out:
# /Users/ediknovik/anaconda3/envs/spatialcells/lib/python3.9/site-packages/scanpy/plotting/_utils.py:429: ImplicitModificationWarning: Trying to modify attribute `._uns` of view, initializing view as actual.
#   adata.uns[value_to_plot + '_colors'] = colors_list

# %% [markdown]
# ## Perform Stage 2 entropy analysis

# %%
### decide whether or  not to include ngfr+ population if want to do stage I vs stage II comparison

# %%
def less_first(a, b):
    return [a,b] if a < b else [b,a]

def delaunay2edges(tri):

    list_of_edges = []

    for triangle in tri.simplices:
        for e1, e2 in [[0,1],[1,2],[2,0]]: # for all edges of triangle
            list_of_edges.append(less_first(triangle[e1],triangle[e2])) # always lesser index first

    array_of_edges = np.unique(list_of_edges, axis=0) # remove duplicates

    list_of_lengths = []

    for p1,p2 in array_of_edges:
        x1, y1 = tri.points[p1]
        x2, y2 = tri.points[p2]
        list_of_lengths.append((x1-x2)**2 + (y1-y2)**2)

    array_of_lengths = np.sqrt(np.array(list_of_lengths))

    return array_of_edges, array_of_lengths

# %%
def make_graph(df, node_attribute_name='lineage_grouped', plot_graph=False):
    coordinates = np.column_stack((df['X_centroid'], df['Y_centroid']))
    tri = Delaunay(coordinates)

    edges, lengths = delaunay2edges(tri)
    # pruning the graph can be done later - use full graph from Delaunay tri for now
    ''' 
    criterion = np.argwhere(lengths < 30).flatten() # can convert pixels to microns
    selected_edges = edges[criterion]
    print('Removed', len(edges) - len(selected_edges), 'edges')
    '''
    cellids = df['CellID'].reset_index(drop=True)
    
    # map cellids to nodes that connect edges
    for i, (ind1, ind2) in enumerate(edges):
        edges[i] = [cellids[ind1], cellids[ind2]]
    
    # create graph object
    G = nx.Graph()
    G.add_nodes_from(cellids)
    G.add_edges_from(edges) # G.add_edges_from(selected_edges)

    if plot_graph:
        nx.draw(G, with_labels=False, node_size=5, node_color='lightgreen')

    # add weights to graph edges
    for i, e in enumerate(G.edges()):
        G[e[0]][e[1]]['weight'] = lengths[i]

    lineages = df[node_attribute_name]
    lineages.index = df['CellID']
    # add attribute to each node
    nx.set_node_attributes(G, lineages, name=node_attribute_name)
    ### G.nodes[5510]['lineage2'] # example how to access node attribute

    graph_dict = nx.to_dict_of_dicts(G)

    # calculate average num nhbrs across cells
    num_nbhrs = []
    for k, v in graph_dict.items():
        num_nbhrs.append(len(v))
    print(f'Average number of neighbors per cell = {np.mean(num_nbhrs)}')

    return G, graph_dict

# %%
def calculate_spatial_entropy(df, G, graph_dict, node_attribute_name='lineage_grouped', base=None):
    lineage_list = df[node_attribute_name].unique().tolist() # E.g. # lineage_list = ['MART1+ MITF- SOX9+', 'MART1- MITF- SOX9-', 'MART1+ MITF- SOX9-', 'MART1+ MITF+ SOX9+', 'MART1+ MITF+ SOX9-', 'MART1- MITF+ SOX9+', 'MART1- MITF+ SOX9-', 'MART1- MITF- SOX9+']
    spatial_entropy_dict = dict.fromkeys(lineage_list)

    for i, lineage_name in enumerate(lineage_list):
        # nodes for class i
        # nodes_class_i = [x for x,y in G.nodes(data=True) if y[node_attribute_name]==lineage_list[i]] # will need unique lineage2 strings to loop through
        nodes_class_i = []
        for x, y in G.nodes(data=True):
            if str(y[node_attribute_name])==str(lineage_list[i]):
                nodes_class_i.append(x)
        # print(f'Number of nodes with lineage {lineage_name}  = {len(nodes_class_i)}')

        neighbor_i_dicts_list = [graph_dict[x] for x in nodes_class_i]
        compare_lineages = copy.deepcopy(lineage_list)
        del compare_lineages[i]

        L_ik = dict.fromkeys(compare_lineages, 0) # count of neighbors where lineage k != i
        d_ik = dict.fromkeys(compare_lineages, 0) # average distance between neighbors where lineage k != i
        for nhbrs_dict in neighbor_i_dicts_list:
            for cell, edge in nhbrs_dict.items():
                # access node attribute
                attribute = G.nodes[cell][node_attribute_name]
                if str(attribute) != str(lineage_list[i]):
                    L_ik[attribute] += 1
                    d_ik[attribute] += edge['weight']

        # for attribute, count in L_ik.items():
        #     if count != 0:
        #         d_ik[attribute] /= count

        L_i = sum(L_ik.values()) * 100 # scaling factor for vizualization
        # L_i /= G.number_of_edges()
        d_i = sum(d_ik.values())

        spatial_entropy_dict[lineage_name] = {'L_i': L_i, 'd_i': d_i}
    # print(spatial_entropy_dict)
    lineages = df[node_attribute_name]
    p = lineages.value_counts(normalize=True, sort=False) # proportion of lineage counts

    spatial_entropy_df = pd.DataFrame.from_dict(spatial_entropy_dict, orient='index')
    spatial_entropy_df['ratio_i'] = spatial_entropy_df['L_i'] / spatial_entropy_df['d_i']
    # print(spatial_entropy_df)
    w = pd.merge(spatial_entropy_df, p, how='inner', left_index=True, right_index=True)
    w = w.drop(columns=['L_i', 'd_i'])
    # print(w)
    base = 2 if base is None else base
    H_spatial = -(w['ratio_i'] * w[node_attribute_name] * np.log(w[node_attribute_name])/np.log(base)).sum()

    return H_spatial

# %% [markdown]
# ### Function to aggregate spatial entropy across patients

# %%
def heterogeneity_per_sample(adata, node_attribute_name, sample_column_name='imageid'):
    data = adata.copy() # stage 2 samples contain all tumor cells by default

    sample_list = data.obs[sample_column_name].unique().tolist()
    H_spatial_dict = {}
    for sample in sample_list:
        print(sample)
        if sample == 'Other':
            continue
        df = data[data.obs[sample_column_name] == sample].obs
        G, graph_dict = make_graph(df, node_attribute_name=node_attribute_name)
        H_spatial = calculate_spatial_entropy(df, G, graph_dict, node_attribute_name=node_attribute_name)
        H_spatial_dict[sample] = H_spatial
    H_spatial_df = pd.DataFrame.from_dict(H_spatial_dict, orient='index').reset_index().rename(columns={'index': 'sample', 0:'H_spatial'}).sort_values(by='H_spatial', ascending=False)

    fig, ax = plt.subplots(figsize=(12,10))
    sns.scatterplot(x=H_spatial_df['sample'], y=H_spatial_df['H_spatial'], color='black', ax=ax)
    ax.set_title(f'Spatial heterogeneity of {node_attribute_name} across samples', fontsize=15)
    ax.set_xlabel('Sample ID')
    ax.set_ylabel('Spatial entropy')
    ax.tick_params(labelrotation=90)
    ax.xaxis.grid(True) # Show the vertical gridlines
    fig.tight_layout()
    plt.savefig(f"/Users/ediknovik/Dropbox/Harvard-University/Sorger-HMS-Postdoc/PCA-Melanoma-Analysis/figures/spatial_entropy/spatial_entropy_stage_2_{node_attribute_name}_across_samples.pdf", format="pdf", bbox_inches="tight")

# %%
heterogeneity_per_sample(adata, node_attribute_name='simplified_phenotype', sample_column_name='contiguous_spatial')
# Out:
# LSP13102_1
# Average number of neighbors per cell = 5.997112922002328
# Other
# LSP15156_1
# Average number of neighbors per cell = 5.9997343745849605
# LSP13078_1
# Average number of neighbors per cell = 5.999682302181867
# LSP13186_1
# Average number of neighbors per cell = 5.999737217262198
# LSP15120_2
# Average number of neighbors per cell = 5.9964717480413015
# LSP15120_1
# Average number of neighbors per cell = 5.998657042135303
# LSP15138_1
# Average number of neighbors per cell = 5.9976640971735575
# LSP15210_2
# Average number of neighbors per cell = 5.998485789718901
# LSP15210_1
# Average number of neighbors per cell = 5.998641324859226
# LSP15183
# Average number of neighbors per cell = 5.998918594172424
# LSP13179_1
# Average number of neighbors per cell = 5.999410192608976
# LSP15219_a_2
# Average number of neighbors per cell = 5.998530546269424
# LSP15219_a_1
# Average number of neighbors per cell = 5.9989697890643106
# LSP15219_b_1
# Average number of neighbors per cell = 5.995647873392681
# LSP15219_b_2
# Average number of neighbors per cell = 5.996288100506817
# LSP15129_1
# Average number of neighbors per cell = 5.999735292775318
# LSP15129_2
# Average number of neighbors per cell = 5.999545106301475
# LSP15192_2
# Average number of neighbors per cell = 5.999361077534105
# LSP15192_1
# Average number of neighbors per cell = 5.9998280636021395

# %%
# df1 = adata[adata.obs.contiguous_spatial == 'Other'].obs
# df1[df1['CellID'] == 39836]
# print(adata.obs.contiguous_spatial.unique().tolist()))
# Out:
#                                     X_centroid    Y_centroid  Area  \
# LSP15192--unmicst_cellRing_39836  61255.601407   6450.425557   853
# LSP15201--unmicst_cellRing_39836  46257.142132  10326.015228   591
#
#                                   MajorAxisLength  MinorAxisLength  \
# LSP15192--unmicst_cellRing_39836        37.160261        29.253973
# LSP15201--unmicst_cellRing_39836        30.318328        25.138229
#
#                                   Eccentricity  Solidity    Extent  \
# LSP15192--unmicst_cellRing_39836      0.616649  0.975973  0.764337
# LSP15201--unmicst_cellRing_39836      0.559037  0.957861  0.815172
#
#                                   Orientation  CellID  ...       KEEP   LOSE  \
# LSP15192--unmicst_cellRing_39836     1.160697   39836  ...  undefined  Other
# LSP15201--unmicst_cellRing_39836     0.130661   39836  ...      Other  Other
#
#                                          phenotype       MART1class MART1pos  \
# LSP15192--unmicst_cellRing_39836  SOX10+SOX9-NGFR+  failed_classify   MART1-
# LSP15201--unmicst_cellRing_39836  SOX10+SOX9-NGFR-  failed_classify   MART1-
#
#                                              phenotypev2 imageid_rename  \
# LSP15192--unmicst_cellRing_39836        SOX10+SOX9-NGFR+       LSP15192
# LSP15201--unmicst_cellRing_39836  SOX10+SOX9-NGFR-MART1-       LSP15201
#
#                                  contiguous_spatial   case  \
# LSP15192--unmicst_cellRing_39836              Other  MEL82
# LSP15201--unmicst_cellRing_39836              Other  MEL83
#
#                                  simplified_phenotype
# LSP15192--unmicst_cellRing_39836     SOX9-NGFR+MART1-
# LSP15201--unmicst_cellRing_39836     SOX10+SOX9-NGFR-
#
# [2 rows x 23 columns]

# %%
def heterogeneity_by_GeoMX_regions(adata, node_attribute_name):
    data = adata.copy() # stage 2 samples contain all tumor cells by default
    data = data[data.obs.geomx_aoi != 'Other']

    geomx_roi_list = data.obs.geomx_aoi.unique().tolist()
    H_spatial_dict = {}
    for geomx_roi in geomx_roi_list:
        geomx_roi_df = data[data.obs.geomx_aoi == geomx_roi].obs
        print(f'GeoMX Region {geomx_roi} shape: {geomx_roi_df.shape}')
        if geomx_roi_df.shape[0] > 10:
            G, graph_dict = make_graph(geomx_roi_df, node_attribute_name=node_attribute_name)
            H_spatial = calculate_spatial_entropy(geomx_roi_df, G, graph_dict, node_attribute_name=node_attribute_name)
            H_spatial_dict[geomx_roi] = H_spatial
        else:
            print(f'Skipping GeoMX Region: {geomx_roi}')

    H_spatial_df = pd.DataFrame.from_dict(H_spatial_dict, orient='index').reset_index().rename(columns={'index': 'GeoMX_ROI', 0:'H_spatial'}).sort_values(by='H_spatial', ascending=False)

    fig, ax = plt.subplots(figsize=(24,20))
    sns.scatterplot(x=H_spatial_df['GeoMX_ROI'], y=H_spatial_df['H_spatial'], color='black', ax=ax)
    ax.set_title(f'Stage II: Regional entropy of {node_attribute_name} across GeoMX regions', fontsize=15)
    ax.set_xlabel('GeoMX Region ID')
    ax.set_ylabel('Regional entropy')
    ax.tick_params(labelrotation=90)
    ax.xaxis.grid(True) # Show the vertical gridlines
    fig.tight_layout()
    plt.savefig(f"/Users/ediknovik/Dropbox/Harvard-University/Sorger-HMS-Postdoc/PCA-Melanoma-Analysis/figures/GeoMX_region_analysis/stage2_spatial_entropy_{node_attribute_name}_across_GeoMX_regions.pdf", format="pdf", bbox_inches="tight")
    
    return H_spatial_df

# %% [markdown]
# ### Function for standard entropy computation per cell (neighborhood)

# %%
def calculate_nbhd_entropy_per_cell(adata, node_attribute_name, sample_column_name='imageid', base=None):
    data = adata.copy() # stage 2 samples contain all tumor cells by default

    full_lineage_list = data.obs[node_attribute_name].unique().tolist()
    print(full_lineage_list)
    sample_list = data.obs[sample_column_name].unique().tolist()
    for sample in sample_list:
        if sample == 'Other':
            continue
        df = data[data.obs[sample_column_name] == sample].obs
        G, graph_dict = make_graph(df, node_attribute_name=node_attribute_name)

        cell_nbhd_dict = dict.fromkeys(df['CellID']) # CellID: [# phenotype1, # phenotype2, # phenotype3, ...]
        for cell_id, nhbrs_dict in graph_dict.items():
            nhbrs_list = list(nhbrs_dict.keys())
            attribute_count_dict = dict.fromkeys(full_lineage_list, 0)
            for cell_nbhr in nhbrs_list:
                # access node attribute
                attribute = G.nodes[cell_nbhr][node_attribute_name]
                attribute_count_dict[attribute] += 1
            cell_nbhd_dict[cell_id] = attribute_count_dict

        cell_nbhd_df = pd.DataFrame.from_dict(cell_nbhd_dict, orient='index')
        cell_nbhd_df = cell_nbhd_df.div(cell_nbhd_df.sum(axis=1), axis=0) # normalize to get probabilities
        cell_nbhd_df = cell_nbhd_df.loc[:, (cell_nbhd_df != 0).any(axis=0)] # remove columns that are all zero
        num_classes = len(cell_nbhd_df.columns)
        max_entropy = round(np.log(num_classes)/np.log(2),2) # max_entropy = log2(num_classes)

        base = 2 if base is None else base
        # 0log(0) = 0, skip zero prob values in rows
        cell_nbhd_df['entropy'] = -(cell_nbhd_df * np.log(cell_nbhd_df, out=np.zeros_like(cell_nbhd_df), where=(cell_nbhd_df!=0))/np.log(base)).sum(axis=1)
        cell_nbhd_df['CellID'] = cell_nbhd_df.index
        cell_nbhd_df = cell_nbhd_df.reset_index(drop=True)
        cell_nbhd_df = pd.merge(cell_nbhd_df, df[['CellID', 'X_centroid', 'Y_centroid']])
        # print(cell_nbhd_df['entropy'].describe())
        
        # Plot Entropy
        fig, ax = plt.subplots(figsize=(10,5))
        p1 = plt.scatter(cell_nbhd_df['X_centroid'], cell_nbhd_df['Y_centroid'], c=cell_nbhd_df['entropy'], s=1, cmap='OrRd', vmin=0, vmax=max_entropy)
        ax.set_facecolor('gray')
        ax.set_title(f'{sample}: Entropy (Min = 0, Max = {max_entropy})', fontsize=15)
        plt.colorbar(p1)
        ax.set_xlabel('X')
        ax.set_ylabel('Y')
        ax.set_xticks([])
        ax.set_yticks([])
        fig.tight_layout()
        plt.savefig(f"/Users/ediknovik/Dropbox/Harvard-University/Sorger-HMS-Postdoc/PCA-Melanoma-Analysis/figures/nbhd_entropy_stage_2_{node_attribute_name}/{sample}_nbhd_entropy.pdf", format="pdf", bbox_inches="tight")

# %%
calculate_nbhd_entropy_per_cell(adata, node_attribute_name='simplified_phenotype', sample_column_name='contiguous_spatial', base=None)
# Out:
# ['SOX9-NGFR+', 'SOX9-NGFR-MART1-', 'SOX9-NGFR-MART1+', 'SOX9+NGFR-MART1+', 'SOX9+NGFR-MART1-', 'SOX9+NGFR+', 'SOX10-SOX9+']
# Average number of neighbors per cell = 5.997112922002328
# Average number of neighbors per cell = 5.9997343745849605
# Average number of neighbors per cell = 5.999682302181867
# Average number of neighbors per cell = 5.999737217262198
# Average number of neighbors per cell = 5.9964717480413015
# Average number of neighbors per cell = 5.998657042135303
# Average number of neighbors per cell = 5.9976640971735575
# Average number of neighbors per cell = 5.998485789718901
# Average number of neighbors per cell = 5.998641324859226
# Average number of neighbors per cell = 5.998918594172424
# Average number of neighbors per cell = 5.999410192608976
# Average number of neighbors per cell = 5.998530546269424
# Average number of neighbors per cell = 5.9989697890643106
# Average number of neighbors per cell = 5.995647873392681
# Average number of neighbors per cell = 5.996288100506817
# Average number of neighbors per cell = 5.999735292775318
# Average number of neighbors per cell = 5.999545106301475
# Average number of neighbors per cell = 5.999361077534105
# Average number of neighbors per cell = 5.9998280636021395

# %% [markdown]
# ### Spatial entropy of GeoMX ROIs

# %%
H_spatial_df = heterogeneity_by_GeoMX_regions(adata, node_attribute_name='simplified_phenotype')
# Out:
# GeoMX Region LSP13099_007 shape: (351, 28)
# Average number of neighbors per cell = 5.84045584045584
# GeoMX Region LSP13099_025 shape: (3, 28)
# Skipping GeoMX Region: LSP13099_025
# GeoMX Region LSP13099_010 shape: (336, 28)
# Average number of neighbors per cell = 5.821428571428571
# GeoMX Region LSP13099_011 shape: (287, 28)
# Average number of neighbors per cell = 5.811846689895471
# GeoMX Region LSP13099_008 shape: (369, 28)
# Average number of neighbors per cell = 5.853658536585366
# GeoMX Region LSP13099_005 shape: (300, 28)
# Average number of neighbors per cell = 5.866666666666666
# GeoMX Region LSP13099_006 shape: (321, 28)
# Average number of neighbors per cell = 5.844236760124611
# GeoMX Region LSP13099_024 shape: (3, 28)
# Skipping GeoMX Region: LSP13099_024
# GeoMX Region LSP13099_009 shape: (217, 28)
# Average number of neighbors per cell = 5.84331797235023
# GeoMX Region LSP13099_027 shape: (20, 28)
# Average number of neighbors per cell = 4.9
# GeoMX Region LSP13099_002 shape: (245, 28)
# Average number of neighbors per cell = 5.812244897959184
# GeoMX Region LSP13099_003 shape: (312, 28)
# Average number of neighbors per cell = 5.839743589743589
# GeoMX Region LSP13099_026 shape: (1, 28)
# Skipping GeoMX Region: LSP13099_026
# GeoMX Region LSP13099_004 shape: (175, 28)
# Average number of neighbors per cell = 5.805714285714286
# GeoMX Region LSP13099_001 shape: (232, 28)
# Average number of neighbors per cell = 5.810344827586207
# GeoMX Region LSP17570_049 shape: (26, 28)
# Average number of neighbors per cell = 5.230769230769231
# GeoMX Region LSP17570_023 shape: (472, 28)
# Average number of neighbors per cell = 5.88135593220339
# GeoMX Region LSP17570_042 shape: (539, 28)
# Average number of neighbors per cell = 5.903525046382189
# GeoMX Region LSP17570_017 shape: (511, 28)
# Average number of neighbors per cell = 5.909980430528376
# GeoMX Region LSP17570_022 shape: (740, 28)
# Average number of neighbors per cell = 5.921621621621622
# GeoMX Region LSP17570_020 shape: (887, 28)
# Average number of neighbors per cell = 5.9458850056369785
# GeoMX Region LSP17570_040 shape: (573, 28)
# Average number of neighbors per cell = 5.895287958115183
# GeoMX Region LSP17570_012 shape: (1033, 28)
# Average number of neighbors per cell = 5.963213939980639
# GeoMX Region LSP17570_041 shape: (562, 28)
# Average number of neighbors per cell = 5.893238434163701
# GeoMX Region LSP17570_026 shape: (569, 28)
# Average number of neighbors per cell = 5.884007029876977
# GeoMX Region LSP17570_024 shape: (635, 28)
# Average number of neighbors per cell = 5.899212598425197
# GeoMX Region LSP17570_053 shape: (41, 28)
# Average number of neighbors per cell = 5.512195121951219
# GeoMX Region LSP17570_038 shape: (328, 28)
# Average number of neighbors per cell = 5.902439024390244
# GeoMX Region LSP17570_001 shape: (570, 28)
# Average number of neighbors per cell = 5.936842105263158
# GeoMX Region LSP17570_018 shape: (958, 28)
# Average number of neighbors per cell = 5.9624217118997915
# GeoMX Region LSP17570_025 shape: (450, 28)
# Average number of neighbors per cell = 5.875555555555556
# GeoMX Region LSP17570_011 shape: (540, 28)
# Average number of neighbors per cell = 5.9
# GeoMX Region LSP17570_014 shape: (1759, 28)
# Average number of neighbors per cell = 5.97384877771461
# GeoMX Region LSP17570_006 shape: (25, 28)
# Average number of neighbors per cell = 5.2
# GeoMX Region LSP17570_005 shape: (548, 28)
# Average number of neighbors per cell = 5.886861313868613
# GeoMX Region LSP17570_002 shape: (582, 28)
# Average number of neighbors per cell = 5.890034364261169
# GeoMX Region LSP17570_032 shape: (461, 28)
# Average number of neighbors per cell = 5.8524945770065075
# GeoMX Region LSP17570_009 shape: (42, 28)
# Average number of neighbors per cell = 5.333333333333333
# GeoMX Region LSP17570_028 shape: (472, 28)
# Average number of neighbors per cell = 5.885593220338983
# GeoMX Region LSP17570_027 shape: (638, 28)
# Average number of neighbors per cell = 5.890282131661442
# GeoMX Region LSP17570_048 shape: (648, 28)
# Average number of neighbors per cell = 5.922839506172839
# GeoMX Region LSP17570_004 shape: (664, 28)
# Average number of neighbors per cell = 5.903614457831325
# GeoMX Region LSP17570_045 shape: (461, 28)
# Average number of neighbors per cell = 5.882863340563992
# GeoMX Region LSP17570_019 shape: (900, 28)
# Average number of neighbors per cell = 5.946666666666666
# GeoMX Region LSP17570_031 shape: (531, 28)
# Average number of neighbors per cell = 5.887005649717514
# GeoMX Region LSP175970_030 shape: (458, 28)
# Average number of neighbors per cell = 5.860262008733624
# GeoMX Region LSP17570_043 shape: (531, 28)
# Average number of neighbors per cell = 5.898305084745763
# GeoMX Region LSP17570_029 shape: (580, 28)
# Average number of neighbors per cell = 5.896551724137931
# GeoMX Region LSP17570_036 shape: (418, 28)
# Average number of neighbors per cell = 5.885167464114833
# GeoMX Region LSP17570_003 shape: (538, 28)
# Average number of neighbors per cell = 5.877323420074349
# GeoMX Region LSP17570_052 shape: (753, 28)
# Average number of neighbors per cell = 5.938911022576361
# GeoMX Region LSP17570_055 shape: (439, 28)
# Average number of neighbors per cell = 5.87243735763098
# GeoMX Region LSP17570_039 shape: (479, 28)
# Average number of neighbors per cell = 5.870563674321503
# GeoMX Region LSP17570_044 shape: (572, 28)
# Average number of neighbors per cell = 5.898601398601398
# GeoMX Region LSP17570_013 shape: (1169, 28)
# Average number of neighbors per cell = 5.958939264328486
# GeoMX Region LSP17570_021 shape: (659, 28)
# Average number of neighbors per cell = 5.905918057663126
# GeoMX Region LSP17570_046 shape: (676, 28)
# Average number of neighbors per cell = 5.905325443786983
# GeoMX Region LSP17570_007 shape: (577, 28)
# Average number of neighbors per cell = 5.889081455805893
# GeoMX Region LSP17570_033 shape: (309, 28)
# Average number of neighbors per cell = 5.857605177993528
# GeoMX Region LSP17570_034 shape: (677, 28)
# Average number of neighbors per cell = 5.89069423929099
# GeoMX Region LSP17570_010 shape: (829, 28)
# Average number of neighbors per cell = 5.915560916767189
# GeoMX Region LSP17570_051 shape: (984, 28)
# Average number of neighbors per cell = 5.943089430894309
# GeoMX Region LSP17570_016 shape: (659, 28)
# Average number of neighbors per cell = 5.936267071320182
# GeoMX Region LSP17570_008 shape: (293, 28)
# Average number of neighbors per cell = 5.829351535836177
# GeoMX Region LSP13075_020 shape: (427, 28)
# Average number of neighbors per cell = 5.9063231850117095
# GeoMX Region LSP13075_021 shape: (348, 28)
# Average number of neighbors per cell = 5.885057471264368
# GeoMX Region LSP13075_022 shape: (4, 28)
# Skipping GeoMX Region: LSP13075_022
# GeoMX Region LSP13075_006 shape: (67, 28)
# Average number of neighbors per cell = 5.582089552238806
# GeoMX Region LSP13075_024 shape: (118, 28)
# Average number of neighbors per cell = 5.711864406779661
# GeoMX Region LSP13075_004 shape: (119, 28)
# Average number of neighbors per cell = 5.647058823529412
# GeoMX Region LSP13075_005 shape: (154, 28)
# Average number of neighbors per cell = 5.7272727272727275
# GeoMX Region LSP13075_025 shape: (85, 28)
# Average number of neighbors per cell = 5.647058823529412
# GeoMX Region LSP13075_018 shape: (83, 28)
# Average number of neighbors per cell = 5.63855421686747
# GeoMX Region LSP13075_027 shape: (66, 28)
# Average number of neighbors per cell = 5.545454545454546
# GeoMX Region LSP13075_032 shape: (13, 28)
# Average number of neighbors per cell = 4.615384615384615
# GeoMX Region LSP13075_019 shape: (31, 28)
# Average number of neighbors per cell = 5.225806451612903
# GeoMX Region LSP13075_007 shape: (149, 28)
# Average number of neighbors per cell = 5.771812080536913
# GeoMX Region LSP13075_008 shape: (231, 28)
# Average number of neighbors per cell = 5.774891774891775
# GeoMX Region LSP13075_045 shape: (131, 28)
# Average number of neighbors per cell = 5.709923664122138
# GeoMX Region LSP13075_030 shape: (1, 28)
# Skipping GeoMX Region: LSP13075_030
# GeoMX Region LSP13075_026 shape: (208, 28)
# Average number of neighbors per cell = 5.8076923076923075
# GeoMX Region LSP13075_017 shape: (144, 28)
# Average number of neighbors per cell = 5.736111111111111
# GeoMX Region LSP13075_023 shape: (98, 28)
# Average number of neighbors per cell = 5.73469387755102
# GeoMX Region LSP13075_010 shape: (175, 28)
# Average number of neighbors per cell = 5.76
# GeoMX Region LSP13075_016 shape: (175, 28)
# Average number of neighbors per cell = 5.748571428571428
# GeoMX Region LSP13075_046 shape: (152, 28)
# Average number of neighbors per cell = 5.7105263157894735
# GeoMX Region LSP13075_011 shape: (181, 28)
# Average number of neighbors per cell = 5.745856353591161
# GeoMX Region LSP13075_009 shape: (161, 28)
# Average number of neighbors per cell = 5.751552795031056
# GeoMX Region LSP13075_028 shape: (11, 28)
# Average number of neighbors per cell = 4.363636363636363
# GeoMX Region LSP13075_034 shape: (1, 28)
# Skipping GeoMX Region: LSP13075_034
# GeoMX Region LSP13075_015 shape: (168, 28)
# Average number of neighbors per cell = 5.75
# GeoMX Region LSP13075_047 shape: (121, 28)
# Average number of neighbors per cell = 5.702479338842975
# GeoMX Region LSP13075_013 shape: (263, 28)
# Average number of neighbors per cell = 5.809885931558935
# GeoMX Region LSP13075_044 shape: (242, 28)
# Average number of neighbors per cell = 5.884297520661157
# GeoMX Region LSP13075_029 shape: (18, 28)
# Average number of neighbors per cell = 5.0
# GeoMX Region LSP13075_035 shape: (7, 28)
# Skipping GeoMX Region: LSP13075_035
# GeoMX Region LSP13075_012 shape: (248, 28)
# Average number of neighbors per cell = 5.782258064516129
# GeoMX Region LSP13075_014 shape: (293, 28)
# Average number of neighbors per cell = 5.822525597269625
# GeoMX Region LSP13075_043 shape: (226, 28)
# Average number of neighbors per cell = 5.8584070796460175
# GeoMX Region LSP13075_042 shape: (185, 28)
# Average number of neighbors per cell = 5.837837837837838
# GeoMX Region LSP13075_039 shape: (67, 28)
# Average number of neighbors per cell = 5.641791044776119
# GeoMX Region LSP13188_003 shape: (3, 28)
# Skipping GeoMX Region: LSP13188_003
# GeoMX Region LSP13188_035 shape: (3, 28)
# Skipping GeoMX Region: LSP13188_035
# GeoMX Region LSP13188_007 shape: (5, 28)
# Skipping GeoMX Region: LSP13188_007
# GeoMX Region LSP13188_038 shape: (337, 28)
# Average number of neighbors per cell = 5.887240356083086
# GeoMX Region LSP13188_039 shape: (405, 28)
# Average number of neighbors per cell = 5.896296296296296
# GeoMX Region LSP13188_023 shape: (291, 28)
# Average number of neighbors per cell = 5.814432989690721
# GeoMX Region LSP13188_006 shape: (15, 28)
# Average number of neighbors per cell = 4.8
# GeoMX Region LSP13188_021 shape: (175, 28)
# Average number of neighbors per cell = 5.782857142857143
# GeoMX Region LSP13188_019 shape: (239, 28)
# Average number of neighbors per cell = 5.866108786610878
# GeoMX Region LSP13188_001 shape: (1, 28)
# Skipping GeoMX Region: LSP13188_001
# GeoMX Region LSP13188_022 shape: (294, 28)
# Average number of neighbors per cell = 5.829931972789115
# GeoMX Region LSP13188_018 shape: (82, 28)
# Average number of neighbors per cell = 5.585365853658536
# GeoMX Region LSP13188_046 shape: (153, 28)
# Average number of neighbors per cell = 5.751633986928105
# GeoMX Region LSP13188_020 shape: (165, 28)
# Average number of neighbors per cell = 5.793939393939394
# GeoMX Region LSP13188_032 shape: (264, 28)
# Average number of neighbors per cell = 5.848484848484849
# GeoMX Region LSP13188_004 shape: (21, 28)
# Average number of neighbors per cell = 4.9523809523809526
# GeoMX Region LSP13188_027 shape: (187, 28)
# Average number of neighbors per cell = 5.775401069518717
# GeoMX Region LSP13188_044 shape: (232, 28)
# Average number of neighbors per cell = 5.801724137931035
# GeoMX Region LSP13188_040 shape: (39, 28)
# Average number of neighbors per cell = 5.435897435897436
# GeoMX Region LSP13188_036 shape: (250, 28)
# Average number of neighbors per cell = 5.792
# GeoMX Region LSP13188_025 shape: (274, 28)
# Average number of neighbors per cell = 5.8321167883211675
# GeoMX Region LSP13188_026 shape: (174, 28)
# Average number of neighbors per cell = 5.7701149425287355
# GeoMX Region LSP13188_045 shape: (211, 28)
# Average number of neighbors per cell = 5.848341232227488
# GeoMX Region LSP13188_042 shape: (204, 28)
# Average number of neighbors per cell = 5.852941176470588
# GeoMX Region LSP13188_031 shape: (267, 28)
# Average number of neighbors per cell = 5.850187265917603
# GeoMX Region LSP13188_033 shape: (155, 28)
# Average number of neighbors per cell = 5.716129032258064
# GeoMX Region LSP13188_024 shape: (241, 28)
# Average number of neighbors per cell = 5.83402489626556
# GeoMX Region LSP13188_037 shape: (201, 28)
# Average number of neighbors per cell = 5.800995024875622
# GeoMX Region LSP13188_043 shape: (239, 28)
# Average number of neighbors per cell = 5.7907949790794975
# GeoMX Region LSP13188_014 shape: (209, 28)
# Average number of neighbors per cell = 5.760765550239235
# GeoMX Region LSP13188_028 shape: (171, 28)
# Average number of neighbors per cell = 5.8011695906432745
# GeoMX Region LSP13188_034 shape: (1, 28)
# Skipping GeoMX Region: LSP13188_034
# GeoMX Region LSP13188_008 shape: (2, 28)
# Skipping GeoMX Region: LSP13188_008
# GeoMX Region LSP13188_016 shape: (179, 28)
# Average number of neighbors per cell = 5.798882681564246
# GeoMX Region LSP13188_029 shape: (229, 28)
# Average number of neighbors per cell = 5.842794759825328
# GeoMX Region LSP13188_009 shape: (3, 28)
# Skipping GeoMX Region: LSP13188_009
# GeoMX Region LSP13188_041 shape: (1, 28)
# Skipping GeoMX Region: LSP13188_041
# GeoMX Region LSP13188_011 shape: (59, 28)
# Average number of neighbors per cell = 5.593220338983051
# GeoMX Region LSP13188_015 shape: (304, 28)
# Average number of neighbors per cell = 5.848684210526316
# GeoMX Region LSP13188_017 shape: (278, 28)
# Average number of neighbors per cell = 5.820143884892087
# GeoMX Region LSP13188_012 shape: (37, 28)
# Average number of neighbors per cell = 5.45945945945946
# GeoMX Region LSP13188_010 shape: (20, 28)
# Average number of neighbors per cell = 4.8
# GeoMX Region LSP17554_015 shape: (63, 28)
# Average number of neighbors per cell = 5.428571428571429
# GeoMX Region LSP17554_014 shape: (29, 28)
# Average number of neighbors per cell = 4.896551724137931
# GeoMX Region LSP17554_013 shape: (61, 28)
# Average number of neighbors per cell = 5.573770491803279
# GeoMX Region LSP17554_012 shape: (54, 28)
# Average number of neighbors per cell = 5.518518518518518
# GeoMX Region LSP17554_010 shape: (129, 28)
# Average number of neighbors per cell = 5.658914728682171
# GeoMX Region LSP17554_001 shape: (49, 28)
# Average number of neighbors per cell = 5.469387755102041
# GeoMX Region LSP17554_020 shape: (18, 28)
# Average number of neighbors per cell = 4.555555555555555
# GeoMX Region LSP17554_011 shape: (11, 28)
# Average number of neighbors per cell = 4.181818181818182
# GeoMX Region LSP17554_023 shape: (290, 28)
# Average number of neighbors per cell = 5.862068965517241
# GeoMX Region LSP17554_009 shape: (200, 28)
# Average number of neighbors per cell = 5.75
# GeoMX Region LSP17554_018 shape: (303, 28)
# Average number of neighbors per cell = 5.8349834983498345
# GeoMX Region LSP17554_024 shape: (182, 28)
# Average number of neighbors per cell = 5.78021978021978
# GeoMX Region LSP17554_029 shape: (49, 28)
# Average number of neighbors per cell = 5.469387755102041
# GeoMX Region LSP17554_027 shape: (210, 28)
# Average number of neighbors per cell = 5.79047619047619
# GeoMX Region LSP17554_030 shape: (34, 28)
# Average number of neighbors per cell = 5.294117647058823
# GeoMX Region LSP17554_022 shape: (295, 28)
# Average number of neighbors per cell = 5.830508474576271
# GeoMX Region LSP17554_026 shape: (349, 28)
# Average number of neighbors per cell = 5.839541547277937
# GeoMX Region LSP17554_028 shape: (148, 28)
# Average number of neighbors per cell = 5.783783783783784
# GeoMX Region LSP17554_025 shape: (469, 28)
# Average number of neighbors per cell = 5.8763326226012795
# GeoMX Region LSP17562_001 shape: (197, 28)
# Average number of neighbors per cell = 5.746192893401015
# GeoMX Region LSP17562_025 shape: (2, 28)
# Skipping GeoMX Region: LSP17562_025
# GeoMX Region LSP17562_005 shape: (132, 28)
# Average number of neighbors per cell = 5.712121212121212
# GeoMX Region LSP17562_022 shape: (103, 28)
# Average number of neighbors per cell = 5.669902912621359
# GeoMX Region LSP17562_004 shape: (123, 28)
# Average number of neighbors per cell = 5.642276422764228
# GeoMX Region LSP17562_003 shape: (161, 28)
# Average number of neighbors per cell = 5.763975155279503
# GeoMX Region LSP17562_016 shape: (399, 28)
# Average number of neighbors per cell = 5.869674185463659
# GeoMX Region LSP17562_006 shape: (172, 28)
# Average number of neighbors per cell = 5.744186046511628
# GeoMX Region LSP17562_017 shape: (141, 28)
# Average number of neighbors per cell = 5.74468085106383
# GeoMX Region LSP17562_027 shape: (161, 28)
# Average number of neighbors per cell = 5.726708074534161
# GeoMX Region LSP17562_020 shape: (187, 28)
# Average number of neighbors per cell = 5.775401069518717
# GeoMX Region LSP17562_009 shape: (105, 28)
# Average number of neighbors per cell = 5.6380952380952385
# GeoMX Region LSP17562_023 shape: (9, 28)
# Skipping GeoMX Region: LSP17562_023
# GeoMX Region LSP17562_011 shape: (220, 28)
# Average number of neighbors per cell = 5.781818181818182
# GeoMX Region LSP17562_010 shape: (224, 28)
# Average number of neighbors per cell = 5.821428571428571
# GeoMX Region LSP17562_021 shape: (106, 28)
# Average number of neighbors per cell = 5.6415094339622645
# GeoMX Region LSP17562_012 shape: (44, 28)
# Average number of neighbors per cell = 5.545454545454546
# GeoMX Region LSP17562_018 shape: (134, 28)
# Average number of neighbors per cell = 5.686567164179104
# GeoMX Region LSP17562_013 shape: (149, 28)
# Average number of neighbors per cell = 5.731543624161074
# GeoMX Region LSP17562_015 shape: (171, 28)
# Average number of neighbors per cell = 5.730994152046784
# GeoMX Region LSP17562_014 shape: (159, 28)
# Average number of neighbors per cell = 5.735849056603773
# GeoMX Region LSP17562_019 shape: (185, 28)
# Average number of neighbors per cell = 5.762162162162162
# GeoMX Region LSP17562_008 shape: (303, 28)
# Average number of neighbors per cell = 5.841584158415841
# GeoMX Region LSP17562_007 shape: (197, 28)
# Average number of neighbors per cell = 5.766497461928934
# GeoMX Region LSP17594_006 shape: (2142, 28)
# Average number of neighbors per cell = 5.953314659197012
# GeoMX Region LSP17594_008 shape: (1290, 28)
# Average number of neighbors per cell = 5.93953488372093
# GeoMX Region LSP17594_007 shape: (1449, 28)
# Average number of neighbors per cell = 5.942028985507246
# GeoMX Region LSP17594_009 shape: (1779, 28)
# Average number of neighbors per cell = 5.9449128724002245
# GeoMX Region LSP17594_030 shape: (422, 28)
# Average number of neighbors per cell = 5.914691943127962
# GeoMX Region LSP17594_015 shape: (429, 28)
# Average number of neighbors per cell = 5.8508158508158505
# GeoMX Region LSP17594_012 shape: (1407, 28)
# Average number of neighbors per cell = 5.947405828002843
# GeoMX Region LSP17594_010 shape: (1654, 28)
# Average number of neighbors per cell = 5.944377267230955
# GeoMX Region LSP17594_020 shape: (446, 28)
# Average number of neighbors per cell = 5.883408071748879
# GeoMX Region LSP17594_011 shape: (1280, 28)
# Average number of neighbors per cell = 5.946875
# GeoMX Region LSP17594_032 shape: (960, 28)
# Average number of neighbors per cell = 5.95
# GeoMX Region LSP17594_003 shape: (432, 28)
# Average number of neighbors per cell = 5.861111111111111
# GeoMX Region LSP17594_028 shape: (258, 28)
# Average number of neighbors per cell = 5.837209302325581
# GeoMX Region LSP17594_031 shape: (699, 28)
# Average number of neighbors per cell = 5.905579399141631
# GeoMX Region LSP17594_005 shape: (209, 28)
# Average number of neighbors per cell = 5.7990430622009566
# GeoMX Region LSP17594_004 shape: (596, 28)
# Average number of neighbors per cell = 5.885906040268456
# GeoMX Region LSP17594_026 shape: (348, 28)
# Average number of neighbors per cell = 5.862068965517241
# GeoMX Region LSP17594_021 shape: (974, 28)
# Average number of neighbors per cell = 5.93223819301848
# GeoMX Region LSP17594_029 shape: (1284, 28)
# Average number of neighbors per cell = 5.975077881619938
# GeoMX Region LSP17594_024 shape: (680, 28)
# Average number of neighbors per cell = 5.9147058823529415
# GeoMX Region LSP17594_025 shape: (456, 28)
# Average number of neighbors per cell = 5.881578947368421
# GeoMX Region LSP17594_014 shape: (1055, 28)
# Average number of neighbors per cell = 5.956398104265403
# GeoMX Region LSP17594_023 shape: (870, 28)
# Average number of neighbors per cell = 5.919540229885057
# GeoMX Region LSP17594_027 shape: (341, 28)
# Average number of neighbors per cell = 5.8240469208211145
# GeoMX Region LSP17594_019 shape: (161, 28)
# Average number of neighbors per cell = 5.726708074534161
# GeoMX Region LSP17594_017 shape: (206, 28)
# Average number of neighbors per cell = 5.796116504854369
# GeoMX Region LSP17594_013 shape: (826, 28)
# Average number of neighbors per cell = 5.963680387409201
# GeoMX Region LSP17594_018 shape: (35, 28)
# Average number of neighbors per cell = 5.371428571428571
# GeoMX Region LSP17582_014 shape: (539, 28)
# Average number of neighbors per cell = 5.8812615955473095
# GeoMX Region LSP17582_005 shape: (643, 28)
# Average number of neighbors per cell = 5.903576982892691
# GeoMX Region LSP17582_015 shape: (337, 28)
# Average number of neighbors per cell = 5.827893175074184
# GeoMX Region LSP17582_013 shape: (663, 28)
# Average number of neighbors per cell = 5.885369532428356
# GeoMX Region LSP17582_006 shape: (810, 28)
# Average number of neighbors per cell = 5.9185185185185185
# GeoMX Region LSP17582_016 shape: (625, 28)
# Average number of neighbors per cell = 5.8944
# GeoMX Region LSP17582_003 shape: (657, 28)
# Average number of neighbors per cell = 5.8812785388127855
# GeoMX Region LSP17582_018 shape: (532, 28)
# Average number of neighbors per cell = 5.906015037593985
# GeoMX Region LSP17582_004 shape: (847, 28)
# Average number of neighbors per cell = 5.910271546635183
# GeoMX Region LSP17582_002 shape: (425, 28)
# Average number of neighbors per cell = 5.863529411764706
# GeoMX Region LSP17582_001 shape: (356, 28)
# Average number of neighbors per cell = 5.865168539325842
# GeoMX Region LSP17582_010 shape: (1070, 28)
# Average number of neighbors per cell = 5.9383177570093455
# GeoMX Region LSP17582_011 shape: (1273, 28)
# Average number of neighbors per cell = 5.937156323644933
# GeoMX Region LSP17582_017 shape: (589, 28)
# Average number of neighbors per cell = 5.887945670628183
# GeoMX Region LSP17582_012 shape: (1213, 28)
# Average number of neighbors per cell = 5.934047815333883
# GeoMX Region LSP17582_008 shape: (690, 28)
# Average number of neighbors per cell = 5.913043478260869
# GeoMX Region LSP17582_019 shape: (956, 28)
# Average number of neighbors per cell = 5.960251046025105
# GeoMX Region LSP17582_007 shape: (364, 28)
# Average number of neighbors per cell = 5.934065934065934
# GeoMX Region LSP17582_021 shape: (181, 28)
# Average number of neighbors per cell = 5.801104972375691
# GeoMX Region LSP17582_020 shape: (193, 28)
# Average number of neighbors per cell = 5.813471502590674
# GeoMX Region LSP17582_022 shape: (56, 28)
# Average number of neighbors per cell = 5.464285714285714
# GeoMX Region LSP13181_003 shape: (579, 28)
# Average number of neighbors per cell = 5.948186528497409
# GeoMX Region LSP13181_004 shape: (692, 28)
# Average number of neighbors per cell = 5.936416184971098
# GeoMX Region LSP13181_005 shape: (651, 28)
# Average number of neighbors per cell = 5.944700460829493
# GeoMX Region LSP13181_007 shape: (3, 28)
# Skipping GeoMX Region: LSP13181_007
# GeoMX Region LSP13181_008 shape: (5, 28)
# Skipping GeoMX Region: LSP13181_008
# GeoMX Region LSP13181_006 shape: (96, 28)
# Average number of neighbors per cell = 5.729166666666667
# GeoMX Region LSP13181_017 shape: (263, 28)
# Average number of neighbors per cell = 5.79467680608365
# GeoMX Region LSP13181_018 shape: (196, 28)
# Average number of neighbors per cell = 5.785714285714286
# GeoMX Region LSP13181_012 shape: (2, 28)
# Skipping GeoMX Region: LSP13181_012
# GeoMX Region LSP13181_001 shape: (26, 28)
# Average number of neighbors per cell = 5.153846153846154
# GeoMX Region LSP13181_023 shape: (441, 28)
# Average number of neighbors per cell = 5.859410430839002
# GeoMX Region LSP13181_019 shape: (370, 28)
# Average number of neighbors per cell = 5.854054054054054
# GeoMX Region LSP13181_034 shape: (2, 28)
# Skipping GeoMX Region: LSP13181_034
# GeoMX Region LSP13181_029 shape: (334, 28)
# Average number of neighbors per cell = 5.826347305389222
# GeoMX Region LSP13181_040 shape: (285, 28)
# Average number of neighbors per cell = 5.838596491228071
# GeoMX Region LSP13181_042 shape: (15, 28)
# Average number of neighbors per cell = 4.666666666666667
# GeoMX Region LSP13181_031 shape: (523, 28)
# Average number of neighbors per cell = 5.938814531548757
# GeoMX Region LSP13181_033 shape: (747, 28)
# Average number of neighbors per cell = 5.930388219544846
# GeoMX Region LSP13181_037 shape: (3, 28)
# Skipping GeoMX Region: LSP13181_037
# GeoMX Region LSP13181_026 shape: (226, 28)
# Average number of neighbors per cell = 5.769911504424779
# GeoMX Region LSP13181_027 shape: (306, 28)
# Average number of neighbors per cell = 5.8431372549019605
# GeoMX Region LSP13181_028 shape: (381, 28)
# Average number of neighbors per cell = 5.874015748031496
# GeoMX Region LSP13181_041 shape: (39, 28)
# Average number of neighbors per cell = 5.487179487179487
# GeoMX Region LSP13181_025 shape: (383, 28)
# Average number of neighbors per cell = 5.87467362924282
# GeoMX Region LSP13181_024 shape: (3, 28)
# Skipping GeoMX Region: LSP13181_024
# GeoMX Region LSP13181_032 shape: (562, 28)
# Average number of neighbors per cell = 5.935943060498221
# GeoMX Region LSP13181_030 shape: (349, 28)
# Average number of neighbors per cell = 5.873925501432665
# GeoMX Region LSP13181_021 shape: (435, 28)
# Average number of neighbors per cell = 5.862068965517241
# GeoMX Region LSP13181_022 shape: (386, 28)
# Average number of neighbors per cell = 5.865284974093265
# GeoMX Region LSP13181_016 shape: (347, 28)
# Average number of neighbors per cell = 5.8328530259366
# GeoMX Region LSP13181_015 shape: (226, 28)
# Average number of neighbors per cell = 5.831858407079646
# GeoMX Region LSP13181_011 shape: (572, 28)
# Average number of neighbors per cell = 5.898601398601398
# GeoMX Region LSP13181_010 shape: (564, 28)
# Average number of neighbors per cell = 5.882978723404255
# GeoMX Region LSP13181_020 shape: (160, 28)
# Average number of neighbors per cell = 5.7375
# GeoMX Region LSP13181_044 shape: (179, 28)
# Average number of neighbors per cell = 5.82122905027933
# GeoMX Region LSP13181_036 shape: (41, 28)
# Average number of neighbors per cell = 5.463414634146342
# GeoMX Region LSP13181_002 shape: (33, 28)
# Average number of neighbors per cell = 5.212121212121212
# GeoMX Region LSP13181_014 shape: (264, 28)
# Average number of neighbors per cell = 5.795454545454546
# GeoMX Region LSP17590_008 shape: (261, 28)
# Average number of neighbors per cell = 5.854406130268199
# GeoMX Region LSP17590_014 shape: (300, 28)
# Average number of neighbors per cell = 5.84
# GeoMX Region LSP17590_007 shape: (42, 28)
# Average number of neighbors per cell = 5.523809523809524
# GeoMX Region LSP17590_002 shape: (260, 28)
# Average number of neighbors per cell = 5.8307692307692305
# GeoMX Region LSP17590_009 shape: (2, 28)
# Skipping GeoMX Region: LSP17590_009
# GeoMX Region LSP17590_003 shape: (480, 28)
# Average number of neighbors per cell = 5.916666666666667
# GeoMX Region LSP17590_004 shape: (457, 28)
# Average number of neighbors per cell = 5.912472647702407
# GeoMX Region LSP17590_013 shape: (487, 28)
# Average number of neighbors per cell = 5.926078028747433
# GeoMX Region LSP17590_006 shape: (477, 28)
# Average number of neighbors per cell = 5.928721174004193
# GeoMX Region LSP17590_005 shape: (488, 28)
# Average number of neighbors per cell = 5.942622950819672
# GeoMX Region LSP17590_010 shape: (49, 28)
# Average number of neighbors per cell = 5.469387755102041
# GeoMX Region LSP17590_011 shape: (88, 28)
# Average number of neighbors per cell = 5.7272727272727275
# GeoMX Region LSP17590_012 shape: (47, 28)
# Average number of neighbors per cell = 5.276595744680851
# GeoMX Region LSP17598_027 shape: (1684, 28)
# Average number of neighbors per cell = 5.971496437054632
# GeoMX Region LSP17598_039 shape: (381, 28)
# Average number of neighbors per cell = 5.868766404199475
# GeoMX Region LSP17598_025 shape: (1006, 28)
# Average number of neighbors per cell = 5.930417495029821
# GeoMX Region LSP17598_024 shape: (857, 28)
# Average number of neighbors per cell = 5.922987164527421
# GeoMX Region LSP17598_026 shape: (659, 28)
# Average number of neighbors per cell = 5.899848254931714
# GeoMX Region LSP17598_028 shape: (680, 28)
# Average number of neighbors per cell = 5.908823529411765
# GeoMX Region LSP17598_035 shape: (1529, 28)
# Average number of neighbors per cell = 5.97514715500327
# GeoMX Region LSP17598_033 shape: (855, 28)
# Average number of neighbors per cell = 5.91578947368421
# GeoMX Region LSP17598_038 shape: (972, 28)
# Average number of neighbors per cell = 5.954732510288066
# GeoMX Region LSP17598_029 shape: (421, 28)
# Average number of neighbors per cell = 5.9002375296912115
# GeoMX Region LSP17598_023 shape: (783, 28)
# Average number of neighbors per cell = 5.915708812260537
# GeoMX Region LSP17598_034 shape: (1407, 28)
# Average number of neighbors per cell = 5.963041933191187
# GeoMX Region LSP17598_032 shape: (829, 28)
# Average number of neighbors per cell = 5.915560916767189
# GeoMX Region LSP17598_031 shape: (888, 28)
# Average number of neighbors per cell = 5.925675675675675
# GeoMX Region LSP17598_030 shape: (981, 28)
# Average number of neighbors per cell = 5.920489296636085
# GeoMX Region LSP17598_040 shape: (1665, 28)
# Average number of neighbors per cell = 5.967567567567568
# GeoMX Region LSP17598_037 shape: (3904, 28)
# Average number of neighbors per cell = 5.988729508196721
# GeoMX Region LSP17598_020 shape: (90, 28)
# Average number of neighbors per cell = 5.622222222222222
# GeoMX Region LSP17598_015 shape: (353, 28)
# Average number of neighbors per cell = 5.903682719546742
# GeoMX Region LSP17598_018 shape: (271, 28)
# Average number of neighbors per cell = 5.81549815498155
# GeoMX Region LSP17598_013 shape: (584, 28)
# Average number of neighbors per cell = 5.9006849315068495
# GeoMX Region LSP17598_014 shape: (835, 28)
# Average number of neighbors per cell = 5.925748502994012
# GeoMX Region LSP17598_019 shape: (564, 28)
# Average number of neighbors per cell = 5.921985815602837
# GeoMX Region LSP17598_017 shape: (260, 28)
# Average number of neighbors per cell = 5.8
# GeoMX Region LSP17598_022 shape: (405, 28)
# Average number of neighbors per cell = 5.85679012345679
# GeoMX Region LSP17598_021 shape: (146, 28)
# Average number of neighbors per cell = 5.794520547945205
# GeoMX Region LSP17598_001 shape: (86, 28)
# Average number of neighbors per cell = 5.604651162790698
# GeoMX Region LSP17598_011 shape: (820, 28)
# Average number of neighbors per cell = 5.946341463414634
# GeoMX Region LSP17598_002 shape: (47, 28)
# Average number of neighbors per cell = 5.48936170212766
# GeoMX Region LSP17598_010 shape: (2160, 28)
# Average number of neighbors per cell = 5.977777777777778
# GeoMX Region LSP17598_003 shape: (802, 28)
# Average number of neighbors per cell = 5.930174563591023
# GeoMX Region LSP17598_004 shape: (1234, 28)
# Average number of neighbors per cell = 5.941653160453809
# GeoMX Region LSP17598_008 shape: (1105, 28)
# Average number of neighbors per cell = 5.94027149321267
# GeoMX Region LSP17598_009 shape: (54, 28)
# Average number of neighbors per cell = 5.62962962962963
# GeoMX Region LSP17598_007 shape: (918, 28)
# Average number of neighbors per cell = 5.919389978213507
# GeoMX Region LSP17598_006 shape: (439, 28)
# Average number of neighbors per cell = 5.85876993166287
# GeoMX Region LSP17558_032 shape: (907, 28)
# Average number of neighbors per cell = 5.933847850055127
# GeoMX Region LSP17558_033 shape: (544, 28)
# Average number of neighbors per cell = 5.911764705882353
# GeoMX Region LSP17558_011 shape: (586, 28)
# Average number of neighbors per cell = 5.924914675767918
# GeoMX Region LSP17558_027 shape: (504, 28)
# Average number of neighbors per cell = 5.888888888888889
# GeoMX Region LSP17558_039 shape: (579, 28)
# Average number of neighbors per cell = 5.8929188255613125
# GeoMX Region LSP17558_010 shape: (582, 28)
# Average number of neighbors per cell = 5.900343642611684
# GeoMX Region LSP17558_029 shape: (397, 28)
# Average number of neighbors per cell = 5.853904282115869
# GeoMX Region LSP17558_031 shape: (513, 28)
# Average number of neighbors per cell = 5.89083820662768
# GeoMX Region LSP17558_008 shape: (1208, 28)
# Average number of neighbors per cell = 5.961920529801325
# GeoMX Region LSP17558_009 shape: (688, 28)
# Average number of neighbors per cell = 5.892441860465116
# GeoMX Region LSP17558_024 shape: (524, 28)
# Average number of neighbors per cell = 5.893129770992366
# GeoMX Region LSP17558_025 shape: (589, 28)
# Average number of neighbors per cell = 5.874363327674024
# GeoMX Region LSP17558_026 shape: (539, 28)
# Average number of neighbors per cell = 5.896103896103896
# GeoMX Region LSP17558_044 shape: (479, 28)
# Average number of neighbors per cell = 5.883089770354906
# GeoMX Region LSP17558_038 shape: (436, 28)
# Average number of neighbors per cell = 5.876146788990826
# GeoMX Region LSP17558_003 shape: (10, 28)
# Skipping GeoMX Region: LSP17558_003
# GeoMX Region LSP17558_057 shape: (1317, 28)
# Average number of neighbors per cell = 5.969627942293091
# GeoMX Region LSP17558_013 shape: (697, 28)
# Average number of neighbors per cell = 5.893830703012912
# GeoMX Region LSP17558_056 shape: (515, 28)
# Average number of neighbors per cell = 5.902912621359223
# GeoMX Region LSP17558_020 shape: (1467, 28)
# Average number of neighbors per cell = 5.9700068166325835
# GeoMX Region LSP17558_054 shape: (735, 28)
# Average number of neighbors per cell = 5.893877551020408
# GeoMX Region LSP17558_012 shape: (536, 28)
# Average number of neighbors per cell = 5.880597014925373
# GeoMX Region LSP17558_042 shape: (98, 28)
# Average number of neighbors per cell = 5.714285714285714
# GeoMX Region LSP17558_041 shape: (635, 28)
# Average number of neighbors per cell = 5.883464566929134
# GeoMX Region LSP17558_034 shape: (1303, 28)
# Average number of neighbors per cell = 5.963161933998465
# GeoMX Region LSP17558_037 shape: (898, 28)
# Average number of neighbors per cell = 5.957683741648107
# GeoMX Region LSP17558_055 shape: (595, 28)
# Average number of neighbors per cell = 5.875630252100841
# GeoMX Region LSP17558_035 shape: (530, 28)
# Average number of neighbors per cell = 5.932075471698113
# GeoMX Region LSP17558_036 shape: (492, 28)
# Average number of neighbors per cell = 5.894308943089431
# GeoMX Region LSP17558_052 shape: (733, 28)
# Average number of neighbors per cell = 5.90450204638472
# GeoMX Region LSP17558_002 shape: (47, 28)
# Average number of neighbors per cell = 5.48936170212766
# GeoMX Region LSP17558_050 shape: (607, 28)
# Average number of neighbors per cell = 5.891268533772652
# GeoMX Region LSP17558_051 shape: (608, 28)
# Average number of neighbors per cell = 5.891447368421052
# GeoMX Region LSP17558_007 shape: (346, 28)
# Average number of neighbors per cell = 5.901734104046243
# GeoMX Region LSP17558_015 shape: (631, 28)
# Average number of neighbors per cell = 5.911251980982567
# GeoMX Region LSP17558_021 shape: (873, 28)
# Average number of neighbors per cell = 5.951890034364261
# GeoMX Region LSP17558_018 shape: (567, 28)
# Average number of neighbors per cell = 5.887125220458554
# GeoMX Region LSP17558_048 shape: (379, 28)
# Average number of neighbors per cell = 5.87335092348285
# GeoMX Region LSP17558_049 shape: (557, 28)
# Average number of neighbors per cell = 5.881508078994614
# GeoMX Region LSP17558_045 shape: (745, 28)
# Average number of neighbors per cell = 5.908724832214765
# GeoMX Region LSP17558_016 shape: (755, 28)
# Average number of neighbors per cell = 5.901986754966887
# GeoMX Region LSP17558_019 shape: (571, 28)
# Average number of neighbors per cell = 5.887915936952715
# GeoMX Region LSP17558_022 shape: (697, 28)
# Average number of neighbors per cell = 5.934002869440459
# GeoMX Region LSP17558_047 shape: (836, 28)
# Average number of neighbors per cell = 5.925837320574162
# GeoMX Region LSP17558_006 shape: (546, 28)
# Average number of neighbors per cell = 5.926739926739927
# GeoMX Region LSP17558_001 shape: (80, 28)
# Average number of neighbors per cell = 5.65
# GeoMX Region LSP17586_023 shape: (157, 28)
# Average number of neighbors per cell = 5.796178343949045
# GeoMX Region LSP17586_029 shape: (465, 28)
# Average number of neighbors per cell = 5.883870967741935
# GeoMX Region LSP17586_022 shape: (925, 28)
# Average number of neighbors per cell = 5.930810810810811
# GeoMX Region LSP17586_027 shape: (954, 28)
# Average number of neighbors per cell = 5.928721174004193
# GeoMX Region LSP17586_024 shape: (472, 28)
# Average number of neighbors per cell = 5.877118644067797
# GeoMX Region LSP17586_031 shape: (782, 28)
# Average number of neighbors per cell = 5.918158567774936
# GeoMX Region LSP17586_021 shape: (938, 28)
# Average number of neighbors per cell = 5.9211087420042645
# GeoMX Region LSP17586_025 shape: (369, 28)
# Average number of neighbors per cell = 5.848238482384824
# GeoMX Region LSP17586_030 shape: (441, 28)
# Average number of neighbors per cell = 5.850340136054422
# GeoMX Region LSP17586_016 shape: (622, 28)
# Average number of neighbors per cell = 5.909967845659164
# GeoMX Region LSP17586_044 shape: (195, 28)
# Average number of neighbors per cell = 5.835897435897436
# GeoMX Region LSP17586_020 shape: (196, 28)
# Average number of neighbors per cell = 5.744897959183674
# GeoMX Region LSP17586_028 shape: (301, 28)
# Average number of neighbors per cell = 5.820598006644518
# GeoMX Region LSP17586_001 shape: (372, 28)
# Average number of neighbors per cell = 5.865591397849462
# GeoMX Region LSP17586_004 shape: (244, 28)
# Average number of neighbors per cell = 5.868852459016393
# GeoMX Region LSP17586_026 shape: (922, 28)
# Average number of neighbors per cell = 5.921908893709327
# GeoMX Region LSP17586_003 shape: (244, 28)
# Average number of neighbors per cell = 5.819672131147541
# GeoMX Region LSP17586_014 shape: (749, 28)
# Average number of neighbors per cell = 5.903871829105474
# GeoMX Region LSP17586_037 shape: (485, 28)
# Average number of neighbors per cell = 5.896907216494846
# GeoMX Region LSP17586_036 shape: (876, 28)
# Average number of neighbors per cell = 5.929223744292237
# GeoMX Region LSP17586_040 shape: (493, 28)
# Average number of neighbors per cell = 5.866125760649087
# GeoMX Region LSP17586_019 shape: (118, 28)
# Average number of neighbors per cell = 5.661016949152542
# GeoMX Region LSP17586_013 shape: (860, 28)
# Average number of neighbors per cell = 5.906976744186046
# GeoMX Region LSP17586_042 shape: (491, 28)
# Average number of neighbors per cell = 5.89816700610998
# GeoMX Region LSP17586_034 shape: (656, 28)
# Average number of neighbors per cell = 5.905487804878049
# GeoMX Region LSP17586_012 shape: (685, 28)
# Average number of neighbors per cell = 5.915328467153285
# GeoMX Region LSP17586_041 shape: (749, 28)
# Average number of neighbors per cell = 5.917222963951936
# GeoMX Region LSP17586_018 shape: (192, 28)
# Average number of neighbors per cell = 5.770833333333333
# GeoMX Region LSP17586_035 shape: (866, 28)
# Average number of neighbors per cell = 5.92147806004619
# GeoMX Region LSP17586_011 shape: (870, 28)
# Average number of neighbors per cell = 5.92183908045977
# GeoMX Region LSP17586_009 shape: (753, 28)
# Average number of neighbors per cell = 5.899070385126162
# GeoMX Region LSP17586_038 shape: (486, 28)
# Average number of neighbors per cell = 5.893004115226337
# GeoMX Region LSP17586_043 shape: (384, 28)
# Average number of neighbors per cell = 5.859375
# GeoMX Region LSP17586_010 shape: (382, 28)
# Average number of neighbors per cell = 5.848167539267016
# GeoMX Region LSP17586_007 shape: (863, 28)
# Average number of neighbors per cell = 5.914252607184241
# GeoMX Region LSP17586_008 shape: (674, 28)
# Average number of neighbors per cell = 5.916913946587537
# GeoMX Region LSP17586_015 shape: (498, 28)
# Average number of neighbors per cell = 5.899598393574297
# GeoMX Region LSP17586_017 shape: (6, 28)
# Skipping GeoMX Region: LSP17586_017
# GeoMX Region LSP17586_033 shape: (190, 28)
# Average number of neighbors per cell = 5.8
# GeoMX Region LSP17586_032 shape: (45, 28)
# Average number of neighbors per cell = 5.511111111111111
# GeoMX Region LSP17586_002 shape: (883, 28)
# Average number of neighbors per cell = 5.918459796149491
# GeoMX Region LSP17586_005 shape: (765, 28)
# Average number of neighbors per cell = 5.918954248366013
# GeoMX Region LSP17586_006 shape: (630, 28)
# Average number of neighbors per cell = 5.901587301587302

# %%
H_spatial_df.to_csv('/Users/ediknovik/Dropbox/Harvard-University/Sorger-HMS-Postdoc/PCA-Melanoma-Analysis/data/stage2_regional_entropy_geomx_rois_06182024.csv', index=False)

# %%
print(adata.obs.geomx_aoi.value_counts())

print((adata.obs.geomx_aoi.value_counts() > 1).sum())
print((adata.obs.geomx_aoi.value_counts() == 1).tail(7))
# Out:
# Other           1574729
# LSP17598_037       3904
# LSP17598_010       2160
# LSP17594_006       2142
# LSP17594_009       1779
#                  ...
# LSP13188_034          1
# LSP13075_030          1
# LSP13188_041          1
# LSP13075_034          1
# LSP13099_026          1
# Name: geomx_aoi, Length: 412, dtype: int64
# 406
# LSP17562_025    False
# LSP13188_001     True
# LSP13188_034     True
# LSP13075_030     True
# LSP13188_041     True
# LSP13075_034     True
# LSP13099_026     True
# Name: geomx_aoi, dtype: bool

# %% [markdown]
# ### Boxplot of spatial entropy - both including and removing stage II samples with high NGFR

# %%
# samples with high NGFR+: LSP 15210, 15192, 13186, 15120, 13078
def heterogeneity_per_stage2_sample(adata, node_attribute_name, sample_column_name='imageid', sample_list=None):
    data = adata.copy() # stage 2 samples contain all tumor cells by default

    if sample_list:
        pass
    else:
        sample_list = data.obs[sample_column_name].unique().tolist()
    H_spatial_dict = {}
    ngfr_high_exclusion_list = ['Other', 'LSP15210', 'LSP15192', 'LSP13186', 'LSP15120', 'LSP13078']
    for sample in sample_list:
        if any([patient for patient in ngfr_high_exclusion_list if patient in sample]):
            continue
        df = data[data.obs[sample_column_name] == sample].obs
        G, graph_dict = make_graph(df, node_attribute_name=node_attribute_name)
        H_spatial = calculate_spatial_entropy(df, G, graph_dict, node_attribute_name=node_attribute_name)
        H_spatial_dict[sample] = H_spatial
    
    H_spatial_df = pd.DataFrame.from_dict(H_spatial_dict, orient='index').reset_index().rename(columns={'index': 'sample', 0:'H_spatial'}).sort_values(by='H_spatial', ascending=False)
    fig, ax = plt.subplots(figsize=(12,10))
    sns.boxplot(data=H_spatial_df, showfliers = False, whis=1, showmeans=True, meanprops={'marker':'o',
                                                                                                'markerfacecolor':'black', 
                                                                                                'markeredgecolor':'black',
                                                                                                'markersize':'8'})
    ax.set_title(f'Spatial heterogeneity of {node_attribute_name} across progression stages', fontsize=15)
    ax.set_xlabel('Progression stage')
    ax.set_ylabel('Spatial entropy')
    fig.tight_layout()

# %%
heterogeneity_per_stage2_sample(adata, node_attribute_name='simplified_phenotype', sample_column_name='contiguous_spatial')
# Out:
# Average number of neighbors per cell = 5.997112922002328
# Average number of neighbors per cell = 5.9997343745849605
# Average number of neighbors per cell = 5.9976640971735575
# Average number of neighbors per cell = 5.998918594172424
# Average number of neighbors per cell = 5.999410192608976
# Average number of neighbors per cell = 5.998530546269424
# Average number of neighbors per cell = 5.9989697890643106
# Average number of neighbors per cell = 5.995647873392681
# Average number of neighbors per cell = 5.996288100506817
# Average number of neighbors per cell = 5.999735292775318
# Average number of neighbors per cell = 5.999545106301475

# %%
# combine spatial-entropy-analysis.ipynb: heterogeneity_by_comparable_progression_stages() for stage I with column for stage II.
def heterogeneity_per_stage2_sample_with_stage1(adata_stage2, adata_stage1, sample_dict_stage1, node_attribute_name_stage2, node_attribute_name_stage1, sample_column_name_stage2='imageid', sample_list_stage2=None, violin_plot=False, include_ngfr_high=False):
    # Assemable stage 2 entropies across samples
    data_stage2 = adata_stage2.copy() # stage 2 samples contain all tumor cells by default

    if sample_list_stage2:
        pass
    else:
        sample_list_stage2 = data_stage2.obs[sample_column_name_stage2].unique().tolist()
    H_spatial_dict_stage2 = {}
    ngfr_high_exclusion_list = ['Other', 'LSP15210', 'LSP15192', 'LSP13186', 'LSP15120', 'LSP13078']
    for sample in sample_list_stage2:
        if include_ngfr_high:
            if sample == 'Other':
                continue
            df_stage2 = data_stage2[data_stage2.obs[sample_column_name_stage2] == sample].obs
            G_stage2, graph_dict_stage2 = make_graph(df_stage2, node_attribute_name=node_attribute_name_stage2)
            H_spatial_stage2 = calculate_spatial_entropy(df_stage2, G_stage2, graph_dict_stage2, node_attribute_name=node_attribute_name_stage2)
            H_spatial_dict_stage2[sample] = H_spatial_stage2
        else:
            if any([patient for patient in ngfr_high_exclusion_list if patient in sample]):
                continue
            df_stage2 = data_stage2[data_stage2.obs[sample_column_name_stage2] == sample].obs
            G_stage2, graph_dict_stage2 = make_graph(df_stage2, node_attribute_name=node_attribute_name_stage2)
            H_spatial_stage2 = calculate_spatial_entropy(df_stage2, G_stage2, graph_dict_stage2, node_attribute_name=node_attribute_name_stage2)
            H_spatial_dict_stage2[sample] = H_spatial_stage2
    
    H_spatial_series_stage2 = pd.Series(H_spatial_dict_stage2.values())

    # Assemble stage 1 entropies across samples
    adata_1 = adata_stage1[adata_stage1.obs.lineage_grouped != 'SOX10-'] # all tumor cells
    adata_2 = adata_1[adata_1.obs.ROI != 'dysplastic nevus']
    data_stage1 = adata_2[adata_2.obs.ROI != 'Other']
    
    H_spatial_dict_stage1 = {}
    for roi_key, sample_list_stage1 in sample_dict_stage1.items():
        H_spatial_dict_per_roi = {}
        #print(roi, sample_list)
        for sample in sample_list_stage1:
            sample_df_stage1 = data_stage1[data_stage1.obs.imageid == sample]
            roi_list = sample_df_stage1.obs.ROI.unique().tolist()
            #print(f'{sample}: {roi_list}')
            roi_dict = {}
            for roi_name in roi_list:
                if roi_key in roi_name:
                    df_stage1 = sample_df_stage1[sample_df_stage1.obs.ROI == roi_name].obs
                    if df_stage1.shape[0] == 0:
                        continue
                    G_stage1, graph_dict_stage1 = make_graph(df_stage1, node_attribute_name=node_attribute_name_stage1)
                    H_spatial_stage1 = calculate_spatial_entropy(df_stage1, G_stage1, graph_dict_stage1, node_attribute_name=node_attribute_name_stage1)
                    roi_dict[roi_name] = H_spatial_stage1
            H_spatial_dict_per_roi[sample] = roi_dict
        H_spatial_dict_stage1[roi_key] = H_spatial_dict_per_roi
    
    roi_progression_dict = {}
    for _, sample_values_dict in H_spatial_dict_stage1.items():
        for _, roi_values_dict in sample_values_dict.items():
            for roi_name, roi_value in roi_values_dict.items():
                roi_short_name = roi_name.split('_')[0]
                roi_progression_dict.setdefault(roi_short_name,[]).append(roi_value)
    
    roi_progression_median_dict = {k:np.median(v) for k, v in roi_progression_dict.items()}
    roi_name_order = list({k:v for k,v in sorted(roi_progression_median_dict.items(), key=lambda x: x[1])}.keys())
    roi_progression_df = pd.DataFrame(dict([ (k, pd.Series(v)) for k,v in roi_progression_dict.items()])) # accounts for different length lists
    roi_progression_df = roi_progression_df[roi_name_order]

    # Combine stage1 and stage2
    roi_progression_df['Stage II'] = H_spatial_series_stage2

    # Plot
    fig, ax = plt.subplots(figsize=(12,10))
    if violin_plot:
        sns.violinplot(data=roi_progression_df, showfliers = False, whis=1, showmeans=True, meanprops={'marker':'o',
                                                                                                    'markerfacecolor':'black', 
                                                                                                    'markeredgecolor':'black',
                                                                                                    'markersize':'8'})
    else:
        sns.boxplot(data=roi_progression_df, showfliers = False, whis=1, showmeans=True, meanprops={'marker':'o',
                                                                                                    'markerfacecolor':'black', 
                                                                                                    'markeredgecolor':'black',
                                                                                                    'markersize':'8'})
    ax.set_title(f'Spatial heterogeneity of tumor phenotypes across progression stages', fontsize=15)
    ax.set_xlabel('Progression stage')
    ax.set_ylabel('Spatial entropy')
    fig.tight_layout()
    if include_ngfr_high:
        plt.savefig(f"/Users/ediknovik/Dropbox/Harvard-University/Sorger-HMS-Postdoc/PCA-Melanoma-Analysis/figures/spatial_entropy/spatial_entropy_tumor_phenotypes_across_comparable_progression_ROIs_and_stage2_including_ngfr_high_samples.pdf", format="pdf", bbox_inches="tight")
    else:
        plt.savefig(f"/Users/ediknovik/Dropbox/Harvard-University/Sorger-HMS-Postdoc/PCA-Melanoma-Analysis/figures/spatial_entropy/spatial_entropy_tumor_phenotypes_across_comparable_progression_ROIs_and_stage2_without_ngfr_high_samples.pdf", format="pdf", bbox_inches="tight")

# %%
# Comparable VGP, RGP, MIS regions for graph analysis
adata_stage1 = scanpy.read_h5ad('/Users/ediknovik/Dropbox/Harvard-University/Sorger-HMS-Postdoc/PCA-Melanoma-Analysis/data/reannotated_progression_ROIs/adata_e24_merged_splits_v4_09182023.h5ad')
adata_stage2 = scanpy.read_h5ad('/Users/ediknovik/Dropbox/Harvard-University/Sorger-HMS-Postdoc/PCA-Melanoma-Analysis/data/pca_stage2_samples/p135_e9_adtumorV5_TV.h5ad')

sample_dict_stage1 = {
               'VGP': ['LSP11411_lower_upper', 'LSP11411_upper', 'LSP11643_right_upper', 'LSP11355_lower_left', 'LSP11355_lower_right_right', 'LSP11355_upper', 'LSP11563_upper', 'LSP11595', 'LSP11747_upper'],
               'RGP': ['LSP11691_left', 'LSP11691_right', 'LSP11411_lower_upper', 'LSP11411_upper', 'LSP12422_left', 'LSP12422_right', 'LSP11315_right_upper', 'LSP11315_left_upper'],
               'MIS': ['LSP11523_upper', 'LSP11387_left_upper', 'LSP11387_right', 'LSP11347_lesion_b', 'LSP11347_lesion_a', 'LSP11691_left', 'LSP11691_right']
              }

heterogeneity_per_stage2_sample_with_stage1(adata_stage2, adata_stage1, sample_dict_stage1, node_attribute_name_stage2='simplified_phenotype', node_attribute_name_stage1='lineage_grouped', sample_column_name_stage2='contiguous_spatial')
# Out:
# Average number of neighbors per cell = 5.997112922002328
# Average number of neighbors per cell = 5.9997343745849605
# Average number of neighbors per cell = 5.9976640971735575
# Average number of neighbors per cell = 5.998918594172424
# Average number of neighbors per cell = 5.999410192608976
# Average number of neighbors per cell = 5.998530546269424
# Average number of neighbors per cell = 5.9989697890643106
# Average number of neighbors per cell = 5.995647873392681
# Average number of neighbors per cell = 5.996288100506817
# Average number of neighbors per cell = 5.999735292775318
# Average number of neighbors per cell = 5.999545106301475
# Average number of neighbors per cell = 5.985957873620863
# Average number of neighbors per cell = 5.974731522425774
# Average number of neighbors per cell = 5.998253681820827
# Average number of neighbors per cell = 5.985996180776575
# Average number of neighbors per cell = 5.993311931514179
# Average number of neighbors per cell = 5.994695700725852
# Average number of neighbors per cell = 5.99125315391085
# Average number of neighbors per cell = 5.994269907132978
# Average number of neighbors per cell = 5.993261060650454
# Average number of neighbors per cell = 5.9557692307692305
# Average number of neighbors per cell = 5.997355937475698
# Average number of neighbors per cell = 5.9890500958116615
# Average number of neighbors per cell = 5.916049382716049
# Average number of neighbors per cell = 5.978792070078377
# Average number of neighbors per cell = 5.966926070038911
# Average number of neighbors per cell = 5.95837669094693
# Average number of neighbors per cell = 5.972272453285112
# Average number of neighbors per cell = 5.988845510317903
# Average number of neighbors per cell = 5.983253588516747
# Average number of neighbors per cell = 5.9972637803963105
# Average number of neighbors per cell = 5.989815164089023
# Average number of neighbors per cell = 5.994421487603306
# Average number of neighbors per cell = 5.975583864118896
# Average number of neighbors per cell = 5.97311271975181
# Average number of neighbors per cell = 5.988329238329238
# Average number of neighbors per cell = 5.976621858562244
# Average number of neighbors per cell = 5.968613775065388
# Average number of neighbors per cell = 5.958709677419355
# Average number of neighbors per cell = 5.949868073878628
# Average number of neighbors per cell = 5.977567886658796

# %%
heterogeneity_per_stage2_sample_with_stage1(adata_stage2, adata_stage1, sample_dict_stage1, node_attribute_name_stage2='simplified_phenotype', node_attribute_name_stage1='lineage_grouped', sample_column_name_stage2='contiguous_spatial', include_ngfr_high=True)
# Out:
# Average number of neighbors per cell = 5.997112922002328
# Average number of neighbors per cell = 5.9997343745849605
# Average number of neighbors per cell = 5.999682302181867
# Average number of neighbors per cell = 5.999737217262198
# Average number of neighbors per cell = 5.9964717480413015
# Average number of neighbors per cell = 5.998657042135303
# Average number of neighbors per cell = 5.9976640971735575
# Average number of neighbors per cell = 5.998485789718901
# Average number of neighbors per cell = 5.998641324859226
# Average number of neighbors per cell = 5.998918594172424
# Average number of neighbors per cell = 5.999410192608976
# Average number of neighbors per cell = 5.998530546269424
# Average number of neighbors per cell = 5.9989697890643106
# Average number of neighbors per cell = 5.995647873392681
# Average number of neighbors per cell = 5.996288100506817
# Average number of neighbors per cell = 5.999735292775318
# Average number of neighbors per cell = 5.999545106301475
# Average number of neighbors per cell = 5.999361077534105
# Average number of neighbors per cell = 5.9998280636021395
# Average number of neighbors per cell = 5.985957873620863
# Average number of neighbors per cell = 5.974731522425774
# Average number of neighbors per cell = 5.998253681820827
# Average number of neighbors per cell = 5.985996180776575
# Average number of neighbors per cell = 5.993311931514179
# Average number of neighbors per cell = 5.994695700725852
# Average number of neighbors per cell = 5.99125315391085
# Average number of neighbors per cell = 5.994269907132978
# Average number of neighbors per cell = 5.993261060650454
# Average number of neighbors per cell = 5.9557692307692305
# Average number of neighbors per cell = 5.997355937475698
# Average number of neighbors per cell = 5.9890500958116615
# Average number of neighbors per cell = 5.916049382716049
# Average number of neighbors per cell = 5.978792070078377
# Average number of neighbors per cell = 5.966926070038911
# Average number of neighbors per cell = 5.95837669094693
# Average number of neighbors per cell = 5.972272453285112
# Average number of neighbors per cell = 5.988845510317903
# Average number of neighbors per cell = 5.983253588516747
# Average number of neighbors per cell = 5.9972637803963105
# Average number of neighbors per cell = 5.989815164089023
# Average number of neighbors per cell = 5.994421487603306
# Average number of neighbors per cell = 5.975583864118896
# Average number of neighbors per cell = 5.97311271975181
# Average number of neighbors per cell = 5.988329238329238
# Average number of neighbors per cell = 5.976621858562244
# Average number of neighbors per cell = 5.968613775065388
# Average number of neighbors per cell = 5.958709677419355
# Average number of neighbors per cell = 5.949868073878628
# Average number of neighbors per cell = 5.977567886658796

# %% [markdown]
# ### Boxplots with statistical significance

# %%
# https://levelup.gitconnected.com/statistics-on-seaborn-plots-with-statannotations-2bfce0394c00
# https://github.com/trevismd/statannotations-tutorials/blob/main/Tutorial_1/Statannotations-Tutorial-1.ipynb
# https://stackoverflow.com/questions/36578458/how-does-one-insert-statistical-annotations-stars-or-p-values
from utils import *
from statannotations.Annotator import Annotator
from scipy.stats import mannwhitneyu

# %%
# combine spatial-entropy-analysis.ipynb: heterogeneity_by_comparable_progression_stages() for stage I with column for stage II.
def heterogeneity_per_stage2_sample_with_stage1(adata_stage2, adata_stage1, sample_dict_stage1, node_attribute_name_stage2, node_attribute_name_stage1, sample_column_name_stage2='imageid', sample_list_stage2=None, violin_plot=False, include_ngfr_high=False):
    # Assemable stage 2 entropies across samples
    data_stage2 = adata_stage2.copy() # stage 2 samples contain all tumor cells by default

    if sample_list_stage2:
        pass
    else:
        sample_list_stage2 = data_stage2.obs[sample_column_name_stage2].unique().tolist()
    H_spatial_dict_stage2 = {}
    ngfr_high_exclusion_list = ['Other', 'LSP15210', 'LSP15192', 'LSP13186', 'LSP15120', 'LSP13078']
    for sample in sample_list_stage2:
        if include_ngfr_high:
            if sample == 'Other':
                continue
            df_stage2 = data_stage2[data_stage2.obs[sample_column_name_stage2] == sample].obs
            G_stage2, graph_dict_stage2 = make_graph(df_stage2, node_attribute_name=node_attribute_name_stage2)
            H_spatial_stage2 = calculate_spatial_entropy(df_stage2, G_stage2, graph_dict_stage2, node_attribute_name=node_attribute_name_stage2)
            H_spatial_dict_stage2[sample] = H_spatial_stage2
        else:
            if any([patient for patient in ngfr_high_exclusion_list if patient in sample]):
                continue
            df_stage2 = data_stage2[data_stage2.obs[sample_column_name_stage2] == sample].obs
            G_stage2, graph_dict_stage2 = make_graph(df_stage2, node_attribute_name=node_attribute_name_stage2)
            H_spatial_stage2 = calculate_spatial_entropy(df_stage2, G_stage2, graph_dict_stage2, node_attribute_name=node_attribute_name_stage2)
            H_spatial_dict_stage2[sample] = H_spatial_stage2
    
    H_spatial_series_stage2 = pd.Series(H_spatial_dict_stage2.values())

    # Assemble stage 1 entropies across samples
    adata_1 = adata_stage1[adata_stage1.obs.lineage_grouped != 'SOX10-'] # all tumor cells
    adata_2 = adata_1[adata_1.obs.ROI != 'dysplastic nevus']
    data_stage1 = adata_2[adata_2.obs.ROI != 'Other']
    
    H_spatial_dict_stage1 = {}
    for roi_key, sample_list_stage1 in sample_dict_stage1.items():
        H_spatial_dict_per_roi = {}
        #print(roi, sample_list)
        for sample in sample_list_stage1:
            sample_df_stage1 = data_stage1[data_stage1.obs.imageid == sample]
            roi_list = sample_df_stage1.obs.ROI.unique().tolist()
            #print(f'{sample}: {roi_list}')
            roi_dict = {}
            for roi_name in roi_list:
                if roi_key in roi_name:
                    df_stage1 = sample_df_stage1[sample_df_stage1.obs.ROI == roi_name].obs
                    if df_stage1.shape[0] == 0:
                        continue
                    G_stage1, graph_dict_stage1 = make_graph(df_stage1, node_attribute_name=node_attribute_name_stage1)
                    H_spatial_stage1 = calculate_spatial_entropy(df_stage1, G_stage1, graph_dict_stage1, node_attribute_name=node_attribute_name_stage1)
                    roi_dict[roi_name] = H_spatial_stage1
            H_spatial_dict_per_roi[sample] = roi_dict
        H_spatial_dict_stage1[roi_key] = H_spatial_dict_per_roi
    
    roi_progression_dict = {}
    for _, sample_values_dict in H_spatial_dict_stage1.items():
        for _, roi_values_dict in sample_values_dict.items():
            for roi_name, roi_value in roi_values_dict.items():
                roi_short_name = roi_name.split('_')[0]
                roi_progression_dict.setdefault(roi_short_name,[]).append(roi_value)
    
    roi_progression_median_dict = {k:np.median(v) for k, v in roi_progression_dict.items()}
    roi_name_order = list({k:v for k,v in sorted(roi_progression_median_dict.items(), key=lambda x: x[1])}.keys())
    roi_progression_df = pd.DataFrame(dict([ (k, pd.Series(v)) for k,v in roi_progression_dict.items()])) # accounts for different length lists
    roi_progression_df = roi_progression_df[roi_name_order]

    # Combine stage1 and stage2
    roi_progression_df['Stage II'] = H_spatial_series_stage2

    pairs = [
                ('MIS', 'RGP'),
                ('RGP', 'VGP'),
                ('VGP', 'Stage II'),
                ('MIS', 'VGP'),
                ('MIS', 'Stage II'),
                ('RGP', 'Stage II')
            ]

    MIS = roi_progression_df['MIS'].dropna().values
    RGP = roi_progression_df['RGP'].dropna().values
    VGP = roi_progression_df['VGP'].dropna().values
    StageII = roi_progression_df['Stage II'].dropna().values

    stat_results = [
                        mannwhitneyu(MIS, RGP, alternative="two-sided"),
                        mannwhitneyu(RGP, VGP, alternative="two-sided"),
                        mannwhitneyu(VGP, StageII, alternative="two-sided"),
                        mannwhitneyu(MIS, VGP, alternative="two-sided"),
                        mannwhitneyu(MIS, StageII, alternative="two-sided"),
                        mannwhitneyu(RGP, StageII, alternative="two-sided")
                    ]
    print("MIS vs RGP: ", stat_results[0])
    print("RGP vs VGP: ", stat_results[1])
    print("VGP vs Stage II: ", stat_results[2])
    print("MIS vs VGP: ", stat_results[3])
    print("MIS vs Stage II: ", stat_results[4])
    print("RGP vs Stage II: ", stat_results[5])

    pvalues = [result.pvalue for result in stat_results]
    formatted_pvalues = [f"p={p:.2e}" for p in pvalues]

    plotting_params = {
                            'data': roi_progression_df,
                            'showfliers': False,
                            'whis': 1,
                            'showmeans': True,
                            'meanprops': {'marker':'o',
                                        'markerfacecolor':'black', 
                                        'markeredgecolor':'black',
                                        'markersize':'8'}
                    }
    
    # Plot
    fig, ax = plt.subplots(figsize=(12,10))
    if violin_plot:
        sns.violinplot(**plotting_params)
    else:
        sns.boxplot(**plotting_params)
    # add statistical significance annotations
    annotator = Annotator(ax, pairs, **plotting_params)
    ### Option 1 - 1e-2 format ###
    # annotator.set_custom_annotations(formatted_pvalues)
    ### Option 2 - *** / ns format ###
    # annotator.set_pvalues(pvalues)
    ### Option 3 - < 0.05 if significant, else show 0.66 format ###
    annotator.configure(text_format="simple", verbose=0)
    annotator.set_pvalues(pvalues)
    annotator.annotate()

    ax.set_title(f'Spatial heterogeneity of tumor phenotypes across progression stages', fontsize=15)
    ax.set_xlabel('Progression stage')
    ax.set_ylabel('Spatial entropy')
    fig.tight_layout()    
    if include_ngfr_high:
        plt.savefig(f"/Users/ediknovik/Dropbox/Harvard-University/Sorger-HMS-Postdoc/PCA-Melanoma-Analysis/figures/spatial_entropy/spatial_entropy_tumor_phenotypes_across_comparable_progression_ROIs_and_stage2_including_ngfr_high_samples_with_significance.pdf", format="pdf", bbox_inches="tight")
    else:
        plt.savefig(f"/Users/ediknovik/Dropbox/Harvard-University/Sorger-HMS-Postdoc/PCA-Melanoma-Analysis/figures/spatial_entropy/spatial_entropy_tumor_phenotypes_across_comparable_progression_ROIs_and_stage2_without_ngfr_high_samples_with_significance.pdf", format="pdf", bbox_inches="tight")
    # return roi_progression_df

# %%
# Comparable VGP, RGP, MIS regions for graph analysis
adata_stage1 = scanpy.read_h5ad('/Users/ediknovik/Dropbox/Harvard-University/Sorger-HMS-Postdoc/PCA-Melanoma-Analysis/data/reannotated_progression_ROIs/adata_e24_merged_splits_v4_09182023.h5ad')
adata_stage2 = scanpy.read_h5ad('/Users/ediknovik/Dropbox/Harvard-University/Sorger-HMS-Postdoc/PCA-Melanoma-Analysis/data/pca_stage2_samples/p135_e9_adtumorV5_TV.h5ad')

sample_dict_stage1 = {
               'VGP': ['LSP11411_lower_upper', 'LSP11411_upper', 'LSP11643_right_upper', 'LSP11355_lower_left', 'LSP11355_lower_right_right', 'LSP11355_upper', 'LSP11563_upper', 'LSP11595', 'LSP11747_upper'],
               'RGP': ['LSP11691_left', 'LSP11691_right', 'LSP11411_lower_upper', 'LSP11411_upper', 'LSP12422_left', 'LSP12422_right', 'LSP11315_right_upper', 'LSP11315_left_upper'],
               'MIS': ['LSP11523_upper', 'LSP11387_left_upper', 'LSP11387_right', 'LSP11347_lesion_b', 'LSP11347_lesion_a', 'LSP11691_left', 'LSP11691_right']
              }

heterogeneity_per_stage2_sample_with_stage1(adata_stage2, adata_stage1, sample_dict_stage1, node_attribute_name_stage2='simplified_phenotype', node_attribute_name_stage1='lineage_grouped', sample_column_name_stage2='contiguous_spatial')
# Out:
# Average number of neighbors per cell = 5.997112922002328
# Average number of neighbors per cell = 5.9997343745849605
# Average number of neighbors per cell = 5.9976640971735575
# Average number of neighbors per cell = 5.998918594172424
# Average number of neighbors per cell = 5.999410192608976
# Average number of neighbors per cell = 5.998530546269424
# Average number of neighbors per cell = 5.9989697890643106
# Average number of neighbors per cell = 5.995647873392681
# Average number of neighbors per cell = 5.996288100506817
# Average number of neighbors per cell = 5.999735292775318
# Average number of neighbors per cell = 5.999545106301475
# Average number of neighbors per cell = 5.985957873620863
# Average number of neighbors per cell = 5.974731522425774
# Average number of neighbors per cell = 5.998253681820827
# Average number of neighbors per cell = 5.985996180776575
# Average number of neighbors per cell = 5.993311931514179
# Average number of neighbors per cell = 5.994695700725852
# Average number of neighbors per cell = 5.99125315391085
# Average number of neighbors per cell = 5.994269907132978
# Average number of neighbors per cell = 5.993261060650454
# Average number of neighbors per cell = 5.9557692307692305
# Average number of neighbors per cell = 5.997355937475698
# Average number of neighbors per cell = 5.9890500958116615
# Average number of neighbors per cell = 5.916049382716049
# Average number of neighbors per cell = 5.978792070078377
# Average number of neighbors per cell = 5.966926070038911
# Average number of neighbors per cell = 5.95837669094693
# Average number of neighbors per cell = 5.972272453285112
# Average number of neighbors per cell = 5.988845510317903
# Average number of neighbors per cell = 5.983253588516747
# Average number of neighbors per cell = 5.9972637803963105
# Average number of neighbors per cell = 5.989815164089023
# Average number of neighbors per cell = 5.994421487603306
# Average number of neighbors per cell = 5.975583864118896
# Average number of neighbors per cell = 5.97311271975181
# Average number of neighbors per cell = 5.988329238329238
# Average number of neighbors per cell = 5.976621858562244
# Average number of neighbors per cell = 5.968613775065388
# Average number of neighbors per cell = 5.958709677419355
# Average number of neighbors per cell = 5.949868073878628
# Average number of neighbors per cell = 5.977567886658796
# MIS vs RGP:  MannwhitneyuResult(statistic=11.0, pvalue=0.012457614624797286)
# RGP vs VGP:  MannwhitneyuResult(statistic=28.0, pvalue=0.6604718810601163)
# VGP vs Stage II:  MannwhitneyuResult(statistic=21.0, pvalue=0.010439075899985918)
# MIS vs VGP:  MannwhitneyuResult(statistic=28.0, pvalue=0.012728682084519901)
# MIS vs Stage II:  MannwhitneyuResult(statistic=0.0, pvalue=3.897138871111154e-05)
# RGP vs Stage II:  MannwhitneyuResult(statistic=2.0, pvalue=0.0006464124111182935)

# %%
heterogeneity_per_stage2_sample_with_stage1(adata_stage2, adata_stage1, sample_dict_stage1, node_attribute_name_stage2='simplified_phenotype', node_attribute_name_stage1='lineage_grouped', sample_column_name_stage2='contiguous_spatial', include_ngfr_high=True)
# Out:
# Average number of neighbors per cell = 5.997112922002328
# Average number of neighbors per cell = 5.9997343745849605
# Average number of neighbors per cell = 5.999682302181867
# Average number of neighbors per cell = 5.999737217262198
# Average number of neighbors per cell = 5.9964717480413015
# Average number of neighbors per cell = 5.998657042135303
# Average number of neighbors per cell = 5.9976640971735575
# Average number of neighbors per cell = 5.998485789718901
# Average number of neighbors per cell = 5.998641324859226
# Average number of neighbors per cell = 5.998918594172424
# Average number of neighbors per cell = 5.999410192608976
# Average number of neighbors per cell = 5.998530546269424
# Average number of neighbors per cell = 5.9989697890643106
# Average number of neighbors per cell = 5.995647873392681
# Average number of neighbors per cell = 5.996288100506817
# Average number of neighbors per cell = 5.999735292775318
# Average number of neighbors per cell = 5.999545106301475
# Average number of neighbors per cell = 5.999361077534105
# Average number of neighbors per cell = 5.9998280636021395
# Average number of neighbors per cell = 5.985957873620863
# Average number of neighbors per cell = 5.974731522425774
# Average number of neighbors per cell = 5.998253681820827
# Average number of neighbors per cell = 5.985996180776575
# Average number of neighbors per cell = 5.993311931514179
# Average number of neighbors per cell = 5.994695700725852
# Average number of neighbors per cell = 5.99125315391085
# Average number of neighbors per cell = 5.994269907132978
# Average number of neighbors per cell = 5.993261060650454
# Average number of neighbors per cell = 5.9557692307692305
# Average number of neighbors per cell = 5.997355937475698
# Average number of neighbors per cell = 5.9890500958116615
# Average number of neighbors per cell = 5.916049382716049
# Average number of neighbors per cell = 5.978792070078377
# Average number of neighbors per cell = 5.966926070038911
# Average number of neighbors per cell = 5.95837669094693
# Average number of neighbors per cell = 5.972272453285112
# Average number of neighbors per cell = 5.988845510317903
# Average number of neighbors per cell = 5.983253588516747
# Average number of neighbors per cell = 5.9972637803963105
# Average number of neighbors per cell = 5.989815164089023
# Average number of neighbors per cell = 5.994421487603306
# Average number of neighbors per cell = 5.975583864118896
# Average number of neighbors per cell = 5.97311271975181
# Average number of neighbors per cell = 5.988329238329238
# Average number of neighbors per cell = 5.976621858562244
# Average number of neighbors per cell = 5.968613775065388
# Average number of neighbors per cell = 5.958709677419355
# Average number of neighbors per cell = 5.949868073878628
# Average number of neighbors per cell = 5.977567886658796
# MIS vs RGP:  MannwhitneyuResult(statistic=11.0, pvalue=0.012457614624797286)
# RGP vs VGP:  MannwhitneyuResult(statistic=28.0, pvalue=0.6604718810601163)
# VGP vs Stage II:  MannwhitneyuResult(statistic=46.0, pvalue=0.14750139990263272)
# MIS vs VGP:  MannwhitneyuResult(statistic=28.0, pvalue=0.012728682084519901)
# MIS vs Stage II:  MannwhitneyuResult(statistic=19.0, pvalue=0.0008581206663936744)
# RGP vs Stage II:  MannwhitneyuResult(statistic=21.0, pvalue=0.12737726669615215)

# %%
pairs = [
            ('MIS', 'RGP'),
            ('RGP', 'VGP'),
            ('VGP', 'Stage II'),
            ('MIS', 'VGP'),
            ('MIS', 'Stage II'),
            ('RGP', 'Stage II')
        ]

MIS = stage1_and_2_df['MIS'].dropna().values
RGP = stage1_and_2_df['RGP'].dropna().values
VGP = stage1_and_2_df['VGP'].dropna().values
StageII = stage1_and_2_df['Stage II'].dropna().values

stat_results = [
                    mannwhitneyu(MIS, RGP, alternative="two-sided"),
                    mannwhitneyu(RGP, VGP, alternative="two-sided"),
                    mannwhitneyu(VGP, StageII, alternative="two-sided"),
                    mannwhitneyu(MIS, VGP, alternative="two-sided"),
                    mannwhitneyu(MIS, StageII, alternative="two-sided"),
                    mannwhitneyu(RGP, StageII, alternative="two-sided")
                ]
print("MIS vs RGP: ", stat_results[0])
print("RGP vs VGP: ", stat_results[1])
print("VGP vs Stage II: ", stat_results[2])
print("MIS vs VGP: ", stat_results[3])
print("MIS vs Stage II: ", stat_results[4])
print("RGP vs Stage II: ", stat_results[5])

pvalues = [result.pvalue for result in stat_results]
formatted_pvalues = [f"p={p:.2e}" for p in pvalues]

plotting_params = {
                        'data': stage1_and_2_df,
                        'showfliers': False,
                        'whis': 1,
                        'showmeans': True,
                        'meanprops': {'marker':'o',
                                      'markerfacecolor':'black', 
                                      'markeredgecolor':'black',
                                      'markersize':'8'}
                  }
# Out:
# MIS vs RGP:  MannwhitneyuResult(statistic=11.0, pvalue=0.012457614624797286)
# RGP vs VGP:  MannwhitneyuResult(statistic=28.0, pvalue=0.6604718810601163)
# VGP vs Stage II:  MannwhitneyuResult(statistic=21.0, pvalue=0.010439075899985918)
# MIS vs VGP:  MannwhitneyuResult(statistic=28.0, pvalue=0.012728682084519901)
# MIS vs Stage II:  MannwhitneyuResult(statistic=0.0, pvalue=3.897138871111154e-05)
# RGP vs Stage II:  MannwhitneyuResult(statistic=2.0, pvalue=0.0006464124111182935)

# %%
fig, ax = plt.subplots(figsize=(12,10))
sns.boxplot(**plotting_params)

# add statistical significance annotations
annotator = Annotator(ax, pairs, **plotting_params)
annotator.set_custom_annotations(formatted_pvalues)
annotator.annotate()

ax.set_title(f'Spatial heterogeneity of tumor phenotypes across progression stages', fontsize=15)
ax.set_xlabel('Progression stage')
ax.set_ylabel('Spatial entropy')
fig.tight_layout()
# Out:
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# MIS vs. RGP: p=1.25e-02
# RGP vs. VGP: p=6.60e-01
# VGP vs. Stage II: p=1.04e-02
# MIS vs. VGP: p=1.27e-02
# RGP vs. Stage II: p=6.46e-04
# MIS vs. Stage II: p=3.90e-05

# %%
fig, ax = plt.subplots(figsize=(12,10))
sns.boxplot(**plotting_params)

# add statistical significance annotations
annotator = Annotator(ax, pairs, **plotting_params)
annotator.set_pvalues(pvalues)
annotator.annotate()

ax.set_title(f'Spatial heterogeneity of tumor phenotypes across progression stages', fontsize=15)
ax.set_xlabel('Progression stage')
ax.set_ylabel('Spatial entropy')
fig.tight_layout()
# Out:
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# MIS vs. RGP: Custom statistical test, P_val:1.246e-02
# RGP vs. VGP: Custom statistical test, P_val:6.605e-01
# VGP vs. Stage II: Custom statistical test, P_val:1.044e-02
# MIS vs. VGP: Custom statistical test, P_val:1.273e-02
# RGP vs. Stage II: Custom statistical test, P_val:6.464e-04
# MIS vs. Stage II: Custom statistical test, P_val:3.897e-05

# %%
fig, ax = plt.subplots(figsize=(12,10))
sns.boxplot(**plotting_params)

# add statistical significance annotations
annotator = Annotator(ax, pairs, **plotting_params)
annotator.configure(text_format="simple", verbose=0)
annotator.set_pvalues(pvalues)
annotator.annotate()

ax.set_title(f'Spatial heterogeneity of tumor phenotypes across progression stages', fontsize=15)
ax.set_xlabel('Progression stage')
ax.set_ylabel('Spatial entropy')
fig.tight_layout()
